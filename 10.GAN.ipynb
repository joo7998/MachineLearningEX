# %% [markdown]
# # 생성적 적대 신경망(Generative Adversarial Networks)
# - 가상의 이미지를 생성하는 알고리즘
# - 진짜 같은 가짜를 만들기 위해 GAN 알고리즘 내부에서는 ‘적대적’인 경합을 진행
# - 생성자(Generator) : 가상의 이미지를 만들어 내는 공장
# - 처음엔 랜덤한 픽셀 값으로 채워진 가짜 이미지로 시작해서 판별자의 판별 결과에 따라 지속적으로 업데이트
# - = 판별자(Discriminator)

# %% [markdown]
# # 페이스북의 AI 연구팀- DCGAN(Deep Convolutional GAN)
# - 1) DCGAN은 생성자가 가짜 이미지를 만들 때, 컨볼루션 신경망(CNN)을 이용
# - 컨볼루션 신경망은 앞서 나온 것과 조금 차이
# - 옵티마이저(optimizer)를 사용하는 최적화 과정이나 컴파일하는 과정이 없다 => 판별과 학습이 이곳 생성자에서 일어나는 게 아니기 때문
# - 2) 일부 매개 변수를 삭제하는 풀링(pooling) 과정이 없고, 대신 앞 장에서 배운 패딩(padding) 과정이 포함 (빈곳을 채워서 같은 크기로 맞추)
# - 3) 배치 정규화(Batch Normalization) : 입력 데이터의 평균이 0, 분산이 1이 되도록 재배치, 다음 층으로 입력될 값을 일정하게 재배치하는 역할=> 층의 개수가 늘어나도 안정적인 학습을 진행. => keras BatchNormalization()
# - 4) 생성자의 활성화 함수로는 ReLU() 함수를 쓰고 판별자로 넘겨 주기 직전에는 tanh()
# - tanh() 함수를 쓰면 출력되는 값을 -1.0~+1.0 사이로
# - 판별자에 입력될 MNIST 손글씨의 픽셀 범위도 -1~1로 맞추면 판별 조건이 모두 갖춰집

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
import numpy as np
import matplotlib.pyplot as plt

# %%
import os 
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

# %%
# 생성자 모델
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
# 128은 임의로 정한 노드의 수
# Input_dim=100은 100차원 크기의 랜덤 벡터를 준비해 집어넣
# 7*7 이미지의 최초 크기 (UpSampling2D() =>이미지의 가로, 세로 크기를 2배씩 늘려 => 14x14 => 28x28)
generator.add(BatchNormalization()) 
# 데이터의 배치를 정규 분포로 만드는 배치 정규화
generator.add(Reshape((7, 7, 128)))
# 컨볼루션 레이어가 받아들일 수 있는 형태로 바꾸 = Conv2D() 함수의 input_shape 부분에 들어갈 형태로 정해
generator.add(UpSampling2D()) # 14x14 
generator.add(Conv2D(64, kernel_size=5, padding='same'))
# 커널 크기를 3 => 3x3 크기의 마스크, 
# padding = ‘same’ => 모자라는 부분은 자동으로 0이 채워
generator.add(BatchNormalization())
# 데이터의 배치를 정규 분포로 만드는 배치 정규화
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D()) # 28x28
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
# 한 번 더 컨볼루션 과정을 거친 후 판별자로 값을 넘길 준비

# %%
generator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 6272)              633472
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 6272)              25088
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 7, 7, 128)         0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        204864
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation_1 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 1)         1601
# =================================================================
# Total params: 865,281
# Trainable params: 852,609
# Non-trainable params: 12,672
# _________________________________________________________________

# %%
# 판별자(생성자에서 넘어온 이미지가 가짜인지 진짜인지를 판별(discriminator)) 모델
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
# 노드의 수는 각각 64, 128개, 커널 크기는 5, 5x5 마스크
# stride는 마스크를 몇 칸씩 이동시킬지 => 가로, 세로 크기가 더 줄어 들어 새로운 특징을 뽑아주는 효과
# (드롭아웃이나 풀링처럼 새로운 필터를 적용한 효과)
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
# 로스 함수(binary_crossentropy)와 최적화 함수(adam)를 써서 판별자에 필요한 준비를 마무리
discriminator.trainable = False

# 주의할 점은 이 판별자는 진짜인지 가짜인지 판별만 해 줄 뿐, 자기 자신이 학습을 해서는 안 된다 
# 판별자가 얻은 가중치는 판별자 자신이 학습하는 데 쓰이는 게 아니라 => 생성자로 넘겨 주어 생성자가 업데이트된 이미지를 만들도록 해야
# 따라서 판별자를 만들 때는 가중치를 저장하는 학습 기능을 꺼주어야

# %%
discriminator.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 14, 14, 64)        1664
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 128)         204928
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 6273
# =================================================================
# WARNING:tensorflow:Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
# Total params: 425,730
# Trainable params: 212,865
# Non-trainable params: 212,865
# _________________________________________________________________

# %%
# 생성자와 판별자 모델을 연결시키는 gan 모델 만들기 
ginput = Input(shape=(100,)) # 100 noise 
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)

# %%
gan.compile(loss='binary_crossentropy', optimizer='adam')

# %%
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
# 신경망을 실행시키는 함수 만들기
def gan_train(epoch, batch_size, saving_interval):
    (X_train, _), (_, _) = mnist.load_data()
    X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
    # MNIST 데이터 불러오기
    # 앞서 불러온 MNIST를 다시 이용, 테스트 과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 호출
    X_train = (X_train - 127.5) / 127.5 
    # 127.5를 빼준 뒤 127.5로 나눠서 -1~1사이의 값으로 바꿈
    true = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))
    
    for i in range(epoch):
        # 실제 데이터를 판별자에 입력
        idx = np.random.randint(0, X_train.shape[0], batch_size)
        imgs = X_train[idx]  
        d_loss_real = discriminator.train_on_batch(imgs, true)
     
        # 가상 이미지를 판별자에 입력
        noise = np.random.normal(0, 1, (batch_size, 100))
        gen_imgs = generator.predict(noise)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)
 
        # 판별자와 생성자의 오차 계산
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        g_loss = gan.train_on_batch(noise, true)
 
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)
        
        if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

# %%
# 중간 과정을 이미지로 저장하는 부분. 정해진 인터벌만큼 학습되면 그때 만든 이미지를 gan_images 폴더에 저장하라는 뜻. 이 코드는 본 장의 주된 목표와는 관계가 없어서 소스 코드만 소개한다

# %%
# 4,000번 반복되고(+1을 하는 것에 주의), 배치 크기는 32, 200번마다 결과가 저장됨
gan_train(4001, 32, 200)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function train_on_batch at 0x00000282D84F28B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# WARNING: AutoGraph could not transform <function train_on_batch at 0x00000282D84F28B8> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: No module named 'tensorflow_core.estimator'
# epoch:0  d_loss:0.6940  g_loss:0.6164
# epoch:1  d_loss:0.4393  g_loss:0.2783
# epoch:2  d_loss:0.4497  g_loss:0.0702
# epoch:3  d_loss:0.4808  g_loss:0.0294
# epoch:4  d_loss:0.5335  g_loss:0.0380
# epoch:5  d_loss:0.4841  g_loss:0.1252
# epoch:6  d_loss:0.4415  g_loss:0.3579
# epoch:7  d_loss:0.4929  g_loss:0.4646
# epoch:8  d_loss:0.5242  g_loss:0.4119
# epoch:9  d_loss:0.4955  g_loss:0.4283
# epoch:10  d_loss:0.4532  g_loss:0.4794
# epoch:11  d_loss:0.3861  g_loss:0.7155
# epoch:12  d_loss:0.3459  g_loss:1.1948
# epoch:13  d_loss:0.2968  g_loss:1.8312
# epoch:14  d_loss:0.2592  g_loss:2.5049
# epoch:15  d_loss:0.3220  g_loss:2.7085
# epoch:16  d_loss:0.3164  g_loss:3.0512
# epoch:17  d_loss:0.6222  g_loss:3.0782
# epoch:18  d_loss:0.4689  g_loss:2.8672
# epoch:19  d_loss:0.4761  g_loss:2.5050
# epoch:20  d_loss:0.4987  g_loss:1.4197
# epoch:21  d_loss:0.3834  g_loss:0.6916
# epoch:22  d_loss:0.2248  g_loss:0.4958
# epoch:23  d_loss:0.1404  g_loss:0.6462
# epoch:24  d_loss:0.1159  g_loss:0.8046
# epoch:25  d_loss:0.1116  g_loss:0.5174
# epoch:26  d_loss:0.1030  g_loss:0.3819
# epoch:27  d_loss:0.0975  g_loss:0.6338
# epoch:28  d_loss:0.0821  g_loss:1.2756
# epoch:29  d_loss:0.1471  g_loss:1.0478
# epoch:30  d_loss:0.2832  g_loss:0.8796
# epoch:31  d_loss:0.1441  g_loss:1.5996
# epoch:32  d_loss:0.7040  g_loss:0.2661
# epoch:33  d_loss:0.4405  g_loss:1.2505
# epoch:34  d_loss:0.3865  g_loss:1.4846
# epoch:35  d_loss:0.8254  g_loss:0.2575
# epoch:36  d_loss:0.7811  g_loss:1.0507
# epoch:37  d_loss:0.6644  g_loss:1.5653
# epoch:38  d_loss:1.0407  g_loss:0.5474
# epoch:39  d_loss:0.8419  g_loss:0.7547
# epoch:40  d_loss:0.2789  g_loss:2.2210
# epoch:41  d_loss:0.4864  g_loss:2.0035
# epoch:42  d_loss:0.3088  g_loss:1.4026
# epoch:43  d_loss:0.1726  g_loss:1.3291
# epoch:44  d_loss:0.1051  g_loss:2.0975
# epoch:45  d_loss:0.0940  g_loss:2.9694
# epoch:46  d_loss:0.0654  g_loss:3.5710
# epoch:47  d_loss:0.1348  g_loss:3.8325
# epoch:48  d_loss:0.1529  g_loss:3.3332
# epoch:49  d_loss:0.2975  g_loss:3.1921
# epoch:50  d_loss:0.5760  g_loss:3.7740
# epoch:51  d_loss:0.9335  g_loss:2.5138
# epoch:52  d_loss:0.9741  g_loss:3.0546
# epoch:53  d_loss:0.9106  g_loss:3.6257
# epoch:54  d_loss:1.2747  g_loss:3.2168
# epoch:55  d_loss:1.4090  g_loss:1.8742
# epoch:56  d_loss:1.0858  g_loss:1.5158
# epoch:57  d_loss:0.6792  g_loss:1.7075
# epoch:58  d_loss:0.4914  g_loss:1.7225
# epoch:59  d_loss:0.5073  g_loss:1.9503
# epoch:60  d_loss:0.4889  g_loss:1.7289
# epoch:61  d_loss:0.4500  g_loss:1.2005
# epoch:62  d_loss:0.3489  g_loss:1.1417
# epoch:63  d_loss:0.2449  g_loss:1.5138
# epoch:64  d_loss:0.2944  g_loss:1.4145
# epoch:65  d_loss:0.3126  g_loss:1.3802
# epoch:66  d_loss:0.3235  g_loss:1.4803
# epoch:67  d_loss:0.1634  g_loss:1.4128
# epoch:68  d_loss:0.2304  g_loss:1.6279
# epoch:69  d_loss:0.2625  g_loss:1.4156
# epoch:70  d_loss:0.1654  g_loss:1.4686
# epoch:71  d_loss:0.2507  g_loss:1.2385
# epoch:72  d_loss:0.1914  g_loss:1.3884
# epoch:73  d_loss:0.1980  g_loss:1.0467
# epoch:74  d_loss:0.3208  g_loss:1.0038
# epoch:75  d_loss:0.3112  g_loss:0.9035
# epoch:76  d_loss:0.3291  g_loss:1.0306
# epoch:77  d_loss:0.3053  g_loss:0.9521
# epoch:78  d_loss:0.3146  g_loss:1.0243
# epoch:79  d_loss:0.2602  g_loss:0.8389
# epoch:80  d_loss:0.5133  g_loss:0.6364
# epoch:81  d_loss:0.4673  g_loss:0.5139
# epoch:82  d_loss:0.4769  g_loss:0.6392
# epoch:83  d_loss:0.4042  g_loss:0.8449
# epoch:84  d_loss:0.5286  g_loss:0.6398
# epoch:85  d_loss:0.6858  g_loss:0.7560
# epoch:86  d_loss:0.6011  g_loss:0.7264
# epoch:87  d_loss:0.6719  g_loss:0.8014
# epoch:88  d_loss:1.0028  g_loss:0.7502
# epoch:89  d_loss:0.6000  g_loss:0.9124
# epoch:90  d_loss:0.6419  g_loss:0.8837
# epoch:91  d_loss:0.6133  g_loss:0.9429
# epoch:92  d_loss:0.6255  g_loss:1.0022
# epoch:93  d_loss:0.6125  g_loss:1.1442
# epoch:94  d_loss:0.4133  g_loss:1.3130
# epoch:95  d_loss:0.2993  g_loss:1.9725
# epoch:96  d_loss:0.2776  g_loss:1.9568
# epoch:97  d_loss:0.1803  g_loss:1.8578
# epoch:98  d_loss:0.1597  g_loss:2.2343
# epoch:99  d_loss:0.1611  g_loss:2.1741
# epoch:100  d_loss:0.2579  g_loss:2.4679
# epoch:101  d_loss:0.1917  g_loss:2.6586
# epoch:102  d_loss:0.3195  g_loss:2.2683
# epoch:103  d_loss:0.4198  g_loss:1.9671
# epoch:104  d_loss:0.3149  g_loss:2.3555
# epoch:105  d_loss:0.3916  g_loss:2.9135
# epoch:106  d_loss:0.5119  g_loss:3.1560
# epoch:107  d_loss:0.4764  g_loss:2.5243
# epoch:108  d_loss:0.7553  g_loss:2.2507
# epoch:109  d_loss:1.1490  g_loss:1.4224
# epoch:110  d_loss:0.8161  g_loss:1.6821
# epoch:111  d_loss:0.7183  g_loss:2.2767
# epoch:112  d_loss:0.5574  g_loss:2.4461
# epoch:113  d_loss:0.7071  g_loss:2.2154
# epoch:114  d_loss:0.6692  g_loss:2.0291
# epoch:115  d_loss:0.6884  g_loss:1.6327
# epoch:116  d_loss:0.6275  g_loss:1.3532
# epoch:117  d_loss:0.7024  g_loss:1.4738
# epoch:118  d_loss:0.5635  g_loss:1.5875
# epoch:119  d_loss:0.4720  g_loss:1.8265
# epoch:120  d_loss:0.4400  g_loss:2.0274
# epoch:121  d_loss:0.4466  g_loss:2.1565
# epoch:122  d_loss:0.4205  g_loss:1.9253
# epoch:123  d_loss:0.4728  g_loss:1.6663
# epoch:124  d_loss:0.3867  g_loss:1.8378
# epoch:125  d_loss:0.5626  g_loss:1.6750
# epoch:126  d_loss:0.4093  g_loss:1.9371
# epoch:127  d_loss:0.3975  g_loss:2.1512
# epoch:128  d_loss:0.3279  g_loss:2.0233
# epoch:129  d_loss:0.4822  g_loss:1.6776
# epoch:130  d_loss:0.3284  g_loss:1.7201
# epoch:131  d_loss:0.3379  g_loss:1.7839
# epoch:132  d_loss:0.4698  g_loss:1.5766
# epoch:133  d_loss:0.4841  g_loss:1.4269
# epoch:134  d_loss:0.3959  g_loss:1.3954
# epoch:135  d_loss:0.3909  g_loss:1.4322
# epoch:136  d_loss:0.4516  g_loss:1.5935
# epoch:137  d_loss:0.5150  g_loss:1.4808
# epoch:138  d_loss:0.4552  g_loss:1.5995
# epoch:139  d_loss:0.4159  g_loss:1.2201
# epoch:140  d_loss:0.4316  g_loss:1.3008
# epoch:141  d_loss:0.4111  g_loss:1.4071
# epoch:142  d_loss:0.6263  g_loss:1.3952
# epoch:143  d_loss:0.5723  g_loss:1.4304
# epoch:144  d_loss:0.4390  g_loss:1.6877
# epoch:145  d_loss:0.4979  g_loss:1.6011
# epoch:146  d_loss:0.5833  g_loss:1.5401
# epoch:147  d_loss:0.5192  g_loss:1.4878
# epoch:148  d_loss:0.5371  g_loss:1.5478
# epoch:149  d_loss:0.5405  g_loss:1.4923
# epoch:150  d_loss:0.5368  g_loss:1.4327
# epoch:151  d_loss:0.5399  g_loss:1.6793
# epoch:152  d_loss:0.5525  g_loss:1.6861
# epoch:153  d_loss:0.5108  g_loss:2.0930
# epoch:154  d_loss:0.5487  g_loss:2.2756
# epoch:155  d_loss:0.5042  g_loss:1.9322
# epoch:156  d_loss:0.3925  g_loss:2.0653
# epoch:157  d_loss:0.4469  g_loss:1.6618
# epoch:158  d_loss:0.4158  g_loss:1.9502
# epoch:159  d_loss:0.2955  g_loss:2.5611
# epoch:160  d_loss:0.4331  g_loss:2.6037
# epoch:161  d_loss:0.5611  g_loss:2.3098
# epoch:162  d_loss:0.4321  g_loss:2.0081
# epoch:163  d_loss:0.3523  g_loss:1.8072
# epoch:164  d_loss:0.4660  g_loss:1.8446
# epoch:165  d_loss:0.3277  g_loss:1.9437
# epoch:166  d_loss:0.5868  g_loss:2.0760
# epoch:167  d_loss:0.4714  g_loss:2.0117
# epoch:168  d_loss:0.4676  g_loss:2.0968
# epoch:169  d_loss:0.5351  g_loss:2.1838
# epoch:170  d_loss:0.6572  g_loss:1.6618
# epoch:171  d_loss:0.5416  g_loss:1.6501
# epoch:172  d_loss:0.5083  g_loss:1.5157
# epoch:173  d_loss:0.5265  g_loss:1.6709
# epoch:174  d_loss:0.5309  g_loss:1.9653
# epoch:175  d_loss:0.7393  g_loss:1.7506
# epoch:176  d_loss:0.6311  g_loss:1.2259
# epoch:177  d_loss:0.5671  g_loss:1.1146
# epoch:178  d_loss:0.5383  g_loss:1.3044
# epoch:179  d_loss:0.5766  g_loss:1.3107
# epoch:180  d_loss:0.5288  g_loss:1.7777
# epoch:181  d_loss:0.5936  g_loss:1.7222
# epoch:182  d_loss:0.6047  g_loss:1.7719
# epoch:183  d_loss:0.6670  g_loss:1.2565
# epoch:184  d_loss:0.6346  g_loss:1.1355
# epoch:185  d_loss:0.5820  g_loss:1.0288
# epoch:186  d_loss:0.5347  g_loss:1.2881
# epoch:187  d_loss:0.5293  g_loss:1.4313
# epoch:188  d_loss:0.4796  g_loss:1.3136
# epoch:189  d_loss:0.5562  g_loss:1.6432
# epoch:190  d_loss:0.4570  g_loss:1.5285
# epoch:191  d_loss:0.6619  g_loss:1.2723
# epoch:192  d_loss:0.6241  g_loss:1.0485
# epoch:193  d_loss:0.5497  g_loss:1.0792
# epoch:194  d_loss:0.4688  g_loss:0.9626
# epoch:195  d_loss:0.4317  g_loss:1.1620
# epoch:196  d_loss:0.4392  g_loss:1.2723
# epoch:197  d_loss:0.5112  g_loss:1.3744
# epoch:198  d_loss:0.3429  g_loss:1.5885
# epoch:199  d_loss:0.4252  g_loss:1.5873
# epoch:200  d_loss:0.4023  g_loss:1.7231
# epoch:201  d_loss:0.5008  g_loss:1.4923
# epoch:202  d_loss:0.5731  g_loss:1.3372
# epoch:203  d_loss:0.5089  g_loss:1.3673
# epoch:204  d_loss:0.4532  g_loss:1.2217
# epoch:205  d_loss:0.4030  g_loss:1.5519
# epoch:206  d_loss:0.3862  g_loss:1.6389
# epoch:207  d_loss:0.3464  g_loss:1.7884
# epoch:208  d_loss:0.3873  g_loss:1.5919
# epoch:209  d_loss:0.4449  g_loss:2.0597
# epoch:210  d_loss:0.4799  g_loss:1.6031
# epoch:211  d_loss:0.4378  g_loss:1.6723
# epoch:212  d_loss:0.3737  g_loss:1.6231
# epoch:213  d_loss:0.3307  g_loss:1.6207
# epoch:214  d_loss:0.3492  g_loss:2.0347
# epoch:215  d_loss:0.4578  g_loss:2.3130
# epoch:216  d_loss:0.3355  g_loss:2.2053
# epoch:217  d_loss:0.3077  g_loss:2.4136
# epoch:218  d_loss:0.4231  g_loss:2.0129
# epoch:219  d_loss:0.3710  g_loss:2.3587
# epoch:220  d_loss:0.3041  g_loss:2.2384
# epoch:221  d_loss:0.4156  g_loss:2.3284
# epoch:222  d_loss:0.4103  g_loss:2.6712
# epoch:223  d_loss:0.4366  g_loss:2.8453
# epoch:224  d_loss:0.4391  g_loss:2.6828
# epoch:225  d_loss:0.4995  g_loss:2.6175
# epoch:226  d_loss:0.4424  g_loss:1.6848
# epoch:227  d_loss:0.4698  g_loss:1.9226
# epoch:228  d_loss:0.5374  g_loss:1.5034
# epoch:229  d_loss:0.4339  g_loss:2.0581
# epoch:230  d_loss:0.5194  g_loss:1.7998
# epoch:231  d_loss:0.5843  g_loss:1.9872
# epoch:232  d_loss:0.4629  g_loss:2.0498
# epoch:233  d_loss:0.5106  g_loss:2.1154
# epoch:234  d_loss:0.5128  g_loss:2.0633
# epoch:235  d_loss:0.6113  g_loss:1.6550
# epoch:236  d_loss:0.5410  g_loss:1.7441
# epoch:237  d_loss:0.4644  g_loss:2.0012
# epoch:238  d_loss:0.6303  g_loss:2.0026
# epoch:239  d_loss:0.4879  g_loss:2.0421
# epoch:240  d_loss:0.4454  g_loss:2.1039
# epoch:241  d_loss:0.5418  g_loss:1.8955
# epoch:242  d_loss:0.5214  g_loss:1.9485
# epoch:243  d_loss:0.5030  g_loss:2.0753
# epoch:244  d_loss:0.5237  g_loss:1.9043
# epoch:245  d_loss:0.6639  g_loss:1.6049
# epoch:246  d_loss:0.4483  g_loss:1.7429
# epoch:247  d_loss:0.5214  g_loss:2.0786
# epoch:248  d_loss:0.4127  g_loss:2.2143
# epoch:249  d_loss:0.5439  g_loss:2.0983
# epoch:250  d_loss:0.5249  g_loss:2.2209
# epoch:251  d_loss:0.5425  g_loss:2.1874
# epoch:252  d_loss:0.4050  g_loss:1.9900
# epoch:253  d_loss:0.5229  g_loss:1.9599
# epoch:254  d_loss:0.4627  g_loss:1.9341
# epoch:255  d_loss:0.5066  g_loss:2.0227
# epoch:256  d_loss:0.5119  g_loss:1.7356
# epoch:257  d_loss:0.6448  g_loss:1.8985
# epoch:258  d_loss:0.4145  g_loss:2.3581
# epoch:259  d_loss:0.4457  g_loss:2.3489
# epoch:260  d_loss:0.5139  g_loss:2.3723
# epoch:261  d_loss:0.3939  g_loss:1.9947
# epoch:262  d_loss:0.3888  g_loss:1.9722
# epoch:263  d_loss:0.4346  g_loss:1.9679
# epoch:264  d_loss:0.4266  g_loss:1.9811
# epoch:265  d_loss:0.4023  g_loss:1.9461
# epoch:266  d_loss:0.4631  g_loss:2.1644
# epoch:267  d_loss:0.2895  g_loss:2.2433
# epoch:268  d_loss:0.3781  g_loss:2.2086
# epoch:269  d_loss:0.4265  g_loss:1.9653
# epoch:270  d_loss:0.4952  g_loss:1.6925
# epoch:271  d_loss:0.4664  g_loss:1.9933
# epoch:272  d_loss:0.3994  g_loss:2.3703
# epoch:273  d_loss:0.3773  g_loss:2.4427
# epoch:274  d_loss:0.5258  g_loss:2.5411
# epoch:275  d_loss:0.3359  g_loss:2.2744
# epoch:276  d_loss:0.5407  g_loss:1.8379
# epoch:277  d_loss:0.3412  g_loss:1.6942
# epoch:278  d_loss:0.5639  g_loss:1.4898
# epoch:279  d_loss:0.4782  g_loss:1.8500
# epoch:280  d_loss:0.3833  g_loss:2.1659
# epoch:281  d_loss:0.4199  g_loss:2.1880
# epoch:282  d_loss:0.4600  g_loss:1.8383
# epoch:283  d_loss:0.4868  g_loss:1.9207
# epoch:284  d_loss:0.5597  g_loss:1.9312
# epoch:285  d_loss:0.6574  g_loss:1.7493
# epoch:286  d_loss:0.4631  g_loss:1.7554
# epoch:287  d_loss:0.5725  g_loss:1.6171
# epoch:288  d_loss:0.5909  g_loss:1.8759
# epoch:289  d_loss:0.5061  g_loss:2.1271
# epoch:290  d_loss:0.4390  g_loss:2.1949
# epoch:291  d_loss:0.5578  g_loss:1.9499
# epoch:292  d_loss:0.4683  g_loss:2.0936
# epoch:293  d_loss:0.4781  g_loss:1.7746
# epoch:294  d_loss:0.4598  g_loss:1.9138
# epoch:295  d_loss:0.6554  g_loss:1.4785
# epoch:296  d_loss:0.4514  g_loss:2.1637
# epoch:297  d_loss:0.5250  g_loss:2.1154
# epoch:298  d_loss:0.4570  g_loss:2.0474
# epoch:299  d_loss:0.5771  g_loss:2.1005
# epoch:300  d_loss:0.4387  g_loss:1.8677
# epoch:301  d_loss:0.3856  g_loss:1.8741
# epoch:302  d_loss:0.7048  g_loss:1.4038
# epoch:303  d_loss:0.4976  g_loss:1.4010
# epoch:304  d_loss:0.4813  g_loss:1.8344
# epoch:305  d_loss:0.5749  g_loss:1.7471
# epoch:306  d_loss:0.4614  g_loss:1.7684
# epoch:307  d_loss:0.5249  g_loss:1.9944
# epoch:308  d_loss:0.6549  g_loss:1.7729
# epoch:309  d_loss:0.4458  g_loss:1.9677
# epoch:310  d_loss:0.4741  g_loss:1.6260
# epoch:311  d_loss:0.5007  g_loss:2.0211
# epoch:312  d_loss:0.3978  g_loss:2.2027
# epoch:313  d_loss:0.3964  g_loss:2.4268
# epoch:314  d_loss:0.5953  g_loss:2.1955
# epoch:315  d_loss:0.3653  g_loss:1.8657
# epoch:316  d_loss:0.4426  g_loss:2.0499
# epoch:317  d_loss:0.2761  g_loss:2.1375
# epoch:318  d_loss:0.2819  g_loss:2.5515
# epoch:319  d_loss:0.2282  g_loss:2.7583
# epoch:320  d_loss:0.3516  g_loss:3.1531
# epoch:321  d_loss:0.3107  g_loss:2.5694
# epoch:322  d_loss:0.5655  g_loss:2.5504
# epoch:323  d_loss:0.4406  g_loss:2.4843
# epoch:324  d_loss:0.3378  g_loss:2.8821
# epoch:325  d_loss:0.2358  g_loss:2.8724
# epoch:326  d_loss:0.2723  g_loss:2.7757
# epoch:327  d_loss:0.3782  g_loss:2.8306
# epoch:328  d_loss:0.3898  g_loss:2.4984
# epoch:329  d_loss:0.6103  g_loss:2.3747
# epoch:330  d_loss:0.3821  g_loss:2.2672
# epoch:331  d_loss:0.3807  g_loss:2.2279
# epoch:332  d_loss:0.2980  g_loss:2.7976
# epoch:333  d_loss:0.4447  g_loss:3.5220
# epoch:334  d_loss:0.3724  g_loss:2.9476
# epoch:335  d_loss:0.4872  g_loss:2.4328
# epoch:336  d_loss:0.4800  g_loss:2.2205
# epoch:337  d_loss:0.3236  g_loss:2.2140
# epoch:338  d_loss:0.3032  g_loss:2.0375
# epoch:339  d_loss:0.2835  g_loss:2.3842
# epoch:340  d_loss:0.4027  g_loss:3.1154
# epoch:341  d_loss:0.4856  g_loss:2.6599
# epoch:342  d_loss:0.4534  g_loss:2.7422
# epoch:343  d_loss:0.2182  g_loss:2.9018
# epoch:344  d_loss:0.4800  g_loss:2.7140
# epoch:345  d_loss:0.5322  g_loss:2.1119
# epoch:346  d_loss:0.4390  g_loss:1.8750
# epoch:347  d_loss:0.4438  g_loss:2.1377
# epoch:348  d_loss:0.5323  g_loss:1.7348
# epoch:349  d_loss:0.4570  g_loss:2.0062
# epoch:350  d_loss:0.3541  g_loss:1.9984
# epoch:351  d_loss:0.3679  g_loss:1.7940
# epoch:352  d_loss:0.4379  g_loss:1.2398
# epoch:353  d_loss:0.3163  g_loss:1.7168
# epoch:354  d_loss:0.3660  g_loss:2.1325
# epoch:355  d_loss:0.2623  g_loss:2.8004
# epoch:356  d_loss:0.3067  g_loss:2.4880
# epoch:357  d_loss:0.4240  g_loss:2.3470
# epoch:358  d_loss:0.3396  g_loss:1.9939
# epoch:359  d_loss:0.3921  g_loss:1.7671
# epoch:360  d_loss:0.4774  g_loss:1.5607
# epoch:361  d_loss:0.4491  g_loss:2.0033
# epoch:362  d_loss:0.3149  g_loss:2.3069
# epoch:363  d_loss:0.3677  g_loss:2.4282
# epoch:364  d_loss:0.2652  g_loss:2.5433
# epoch:365  d_loss:0.3804  g_loss:2.4810
# epoch:366  d_loss:0.3284  g_loss:2.2634
# epoch:367  d_loss:0.3556  g_loss:1.9661
# epoch:368  d_loss:0.3456  g_loss:1.9167
# epoch:369  d_loss:0.4709  g_loss:1.7017
# epoch:370  d_loss:0.3396  g_loss:2.2170
# epoch:371  d_loss:0.3533  g_loss:2.4798
# epoch:372  d_loss:0.3481  g_loss:3.7425
# epoch:373  d_loss:0.3161  g_loss:3.0141
# epoch:374  d_loss:0.4549  g_loss:2.1412
# epoch:375  d_loss:0.4088  g_loss:1.8556
# epoch:376  d_loss:0.4350  g_loss:1.3942
# epoch:377  d_loss:0.3353  g_loss:1.9481
# epoch:378  d_loss:0.3905  g_loss:2.2225
# epoch:379  d_loss:0.3942  g_loss:2.9204
# epoch:380  d_loss:0.4433  g_loss:2.6244
# epoch:381  d_loss:0.3498  g_loss:2.2897
# epoch:382  d_loss:0.4298  g_loss:2.0682
# epoch:383  d_loss:0.5878  g_loss:2.0428
# epoch:384  d_loss:0.3679  g_loss:2.1733
# epoch:385  d_loss:0.4506  g_loss:2.4956
# epoch:386  d_loss:0.4599  g_loss:2.1612
# epoch:387  d_loss:0.3351  g_loss:2.0950
# epoch:388  d_loss:0.3714  g_loss:2.0674
# epoch:389  d_loss:0.3851  g_loss:1.9867
# epoch:390  d_loss:0.3217  g_loss:2.1233
# epoch:391  d_loss:0.3488  g_loss:2.0523
# epoch:392  d_loss:0.4029  g_loss:2.0249
# epoch:393  d_loss:0.3797  g_loss:2.5247
# epoch:394  d_loss:0.3464  g_loss:2.0028
# epoch:395  d_loss:0.2716  g_loss:2.6281
# epoch:396  d_loss:0.4540  g_loss:2.7821
# epoch:397  d_loss:0.3494  g_loss:2.3824
# epoch:398  d_loss:0.2892  g_loss:2.7727
# epoch:399  d_loss:0.2435  g_loss:2.8416
# epoch:400  d_loss:0.2004  g_loss:2.6952
# epoch:401  d_loss:0.1969  g_loss:3.3371
# epoch:402  d_loss:0.5874  g_loss:2.5188
# epoch:403  d_loss:0.1758  g_loss:3.0317
# epoch:404  d_loss:0.1260  g_loss:3.6679
# epoch:405  d_loss:0.3664  g_loss:3.0667
# epoch:406  d_loss:0.4928  g_loss:3.4232
# epoch:407  d_loss:0.3690  g_loss:3.5657
# epoch:408  d_loss:0.4961  g_loss:3.4130
# epoch:409  d_loss:0.4008  g_loss:2.9890
# epoch:410  d_loss:0.3825  g_loss:2.9004
# epoch:411  d_loss:0.3806  g_loss:2.6636
# epoch:412  d_loss:0.5002  g_loss:2.4621
# epoch:413  d_loss:0.4693  g_loss:2.2826
# epoch:414  d_loss:0.5094  g_loss:3.0256
# epoch:415  d_loss:0.5676  g_loss:3.3486
# epoch:416  d_loss:0.4271  g_loss:2.7004
# epoch:417  d_loss:0.4562  g_loss:2.3048
# epoch:418  d_loss:0.4573  g_loss:2.1706
# epoch:419  d_loss:0.2997  g_loss:2.8645
# epoch:420  d_loss:0.1641  g_loss:3.3458
# epoch:421  d_loss:0.3097  g_loss:3.5048
# epoch:422  d_loss:0.2626  g_loss:2.9758
# epoch:423  d_loss:0.1325  g_loss:2.8422
# epoch:424  d_loss:0.1762  g_loss:2.6684
# epoch:425  d_loss:0.1950  g_loss:2.9324
# epoch:426  d_loss:0.1704  g_loss:2.6881
# epoch:427  d_loss:0.1986  g_loss:2.9103
# epoch:428  d_loss:0.2033  g_loss:3.1588
# epoch:429  d_loss:0.2361  g_loss:2.9621
# epoch:430  d_loss:0.2179  g_loss:3.1694
# epoch:431  d_loss:0.2401  g_loss:2.8924
# epoch:432  d_loss:0.2515  g_loss:2.1983
# epoch:433  d_loss:0.2553  g_loss:2.2588
# epoch:434  d_loss:0.2031  g_loss:2.6299
# epoch:435  d_loss:0.3543  g_loss:2.3842
# epoch:436  d_loss:0.2399  g_loss:2.6412
# epoch:437  d_loss:0.2991  g_loss:2.2932
# epoch:438  d_loss:0.2633  g_loss:2.6624
# epoch:439  d_loss:0.2535  g_loss:2.1786
# epoch:440  d_loss:0.4441  g_loss:2.2778
# epoch:441  d_loss:0.3573  g_loss:2.6366
# epoch:442  d_loss:0.3551  g_loss:2.6545
# epoch:443  d_loss:0.4372  g_loss:2.5686
# epoch:444  d_loss:0.3203  g_loss:2.0804
# epoch:445  d_loss:0.3164  g_loss:2.3844
# epoch:446  d_loss:0.2937  g_loss:2.2812
# epoch:447  d_loss:0.3236  g_loss:1.9107
# epoch:448  d_loss:0.2794  g_loss:2.3806
# epoch:449  d_loss:0.3945  g_loss:2.3880
# epoch:450  d_loss:0.2211  g_loss:2.6920
# epoch:451  d_loss:0.2766  g_loss:2.7209
# epoch:452  d_loss:0.2952  g_loss:2.3370
# epoch:453  d_loss:0.3685  g_loss:2.4472
# epoch:454  d_loss:0.2983  g_loss:2.0255
# epoch:455  d_loss:0.3159  g_loss:1.7895
# epoch:456  d_loss:0.3138  g_loss:2.2580
# epoch:457  d_loss:0.2702  g_loss:2.9899
# epoch:458  d_loss:0.3583  g_loss:2.7742
# epoch:459  d_loss:0.3827  g_loss:2.7626
# epoch:460  d_loss:0.3845  g_loss:2.1494
# epoch:461  d_loss:0.2708  g_loss:1.6679
# epoch:462  d_loss:0.2931  g_loss:2.3110
# epoch:463  d_loss:0.2093  g_loss:3.2054
# epoch:464  d_loss:0.2525  g_loss:3.1963
# epoch:465  d_loss:0.2357  g_loss:2.9328
# epoch:466  d_loss:0.2772  g_loss:2.6806
# epoch:467  d_loss:0.2215  g_loss:2.4540
# epoch:468  d_loss:0.2553  g_loss:2.1185
# epoch:469  d_loss:0.4043  g_loss:2.3958
# epoch:470  d_loss:0.1983  g_loss:2.6733
# epoch:471  d_loss:0.1809  g_loss:2.7878
# epoch:472  d_loss:0.2453  g_loss:2.9475
# epoch:473  d_loss:0.3071  g_loss:2.6776
# epoch:474  d_loss:0.2965  g_loss:2.3752
# epoch:475  d_loss:0.2168  g_loss:2.3813
# epoch:476  d_loss:0.1340  g_loss:3.0903
# epoch:477  d_loss:0.1884  g_loss:3.2869
# epoch:478  d_loss:0.1470  g_loss:3.0178
# epoch:479  d_loss:0.2471  g_loss:2.3201
# epoch:480  d_loss:0.1244  g_loss:2.6441
# epoch:481  d_loss:0.2390  g_loss:2.7278
# epoch:482  d_loss:0.2043  g_loss:3.0125
# epoch:483  d_loss:0.2082  g_loss:2.8938
# epoch:484  d_loss:0.2568  g_loss:2.4053
# epoch:485  d_loss:0.2538  g_loss:2.4296
# epoch:486  d_loss:0.2955  g_loss:2.2626
# epoch:487  d_loss:0.2192  g_loss:2.7537
# epoch:488  d_loss:0.1816  g_loss:2.7911
# epoch:489  d_loss:0.2350  g_loss:3.2170
# epoch:490  d_loss:0.1597  g_loss:3.3897
# epoch:491  d_loss:0.2746  g_loss:2.9249
# epoch:492  d_loss:0.3372  g_loss:2.3773
# epoch:493  d_loss:0.2611  g_loss:2.4420
# epoch:494  d_loss:0.2873  g_loss:2.8685
# epoch:495  d_loss:0.1371  g_loss:3.2868
# epoch:496  d_loss:0.2444  g_loss:2.9560
# epoch:497  d_loss:0.3012  g_loss:2.0839
# epoch:498  d_loss:0.2781  g_loss:1.6611
# epoch:499  d_loss:0.1943  g_loss:2.4877
# epoch:500  d_loss:0.1389  g_loss:3.0771
# epoch:501  d_loss:0.3294  g_loss:2.9286
# epoch:502  d_loss:0.2460  g_loss:2.3335
# epoch:503  d_loss:0.2489  g_loss:1.8685
# epoch:504  d_loss:0.2885  g_loss:2.0814
# epoch:505  d_loss:0.3105  g_loss:2.0090
# epoch:506  d_loss:0.2338  g_loss:3.2708
# epoch:507  d_loss:0.3095  g_loss:2.9236
# epoch:508  d_loss:0.2258  g_loss:2.5568
# epoch:509  d_loss:0.2952  g_loss:2.5342
# epoch:510  d_loss:0.2252  g_loss:2.3276
# epoch:511  d_loss:0.3360  g_loss:2.1915
# epoch:512  d_loss:0.2589  g_loss:2.6708
# epoch:513  d_loss:0.3071  g_loss:2.9963
# epoch:514  d_loss:0.2204  g_loss:3.0061
# epoch:515  d_loss:0.3124  g_loss:2.1243
# epoch:516  d_loss:0.3153  g_loss:2.0833
# epoch:517  d_loss:0.2277  g_loss:1.6922
# epoch:518  d_loss:0.3094  g_loss:1.9248
# epoch:519  d_loss:0.1839  g_loss:2.5511
# epoch:520  d_loss:0.2062  g_loss:2.7597
# epoch:521  d_loss:0.2578  g_loss:2.9491
# epoch:522  d_loss:0.2126  g_loss:2.8008
# epoch:523  d_loss:0.2506  g_loss:2.9465
# epoch:524  d_loss:0.2372  g_loss:2.8627
# epoch:525  d_loss:0.2402  g_loss:2.4331
# epoch:526  d_loss:0.1853  g_loss:2.3445
# epoch:527  d_loss:0.2489  g_loss:2.7146
# epoch:528  d_loss:0.1856  g_loss:3.4666
# epoch:529  d_loss:0.2671  g_loss:2.4903
# epoch:530  d_loss:0.1851  g_loss:2.7487
# epoch:531  d_loss:0.1742  g_loss:2.8384
# epoch:532  d_loss:0.2410  g_loss:2.7155
# epoch:533  d_loss:0.2695  g_loss:3.0070
# epoch:534  d_loss:0.1939  g_loss:3.5925
# epoch:535  d_loss:0.2209  g_loss:3.0939
# epoch:536  d_loss:0.2438  g_loss:3.1516
# epoch:537  d_loss:0.2208  g_loss:2.6943
# epoch:538  d_loss:0.1856  g_loss:2.1257
# epoch:539  d_loss:0.1618  g_loss:2.7406
# epoch:540  d_loss:0.2210  g_loss:3.1158
# epoch:541  d_loss:0.2585  g_loss:2.7854
# epoch:542  d_loss:0.2307  g_loss:2.6399
# epoch:543  d_loss:0.3748  g_loss:2.3271
# epoch:544  d_loss:0.3125  g_loss:2.5075
# epoch:545  d_loss:0.1656  g_loss:2.9255
# epoch:546  d_loss:0.2263  g_loss:3.5216
# epoch:547  d_loss:0.2755  g_loss:2.7838
# epoch:548  d_loss:0.3286  g_loss:1.9644
# epoch:549  d_loss:0.3303  g_loss:2.2647
# epoch:550  d_loss:0.2029  g_loss:2.5338
# epoch:551  d_loss:0.3608  g_loss:3.1028
# epoch:552  d_loss:0.3884  g_loss:2.3597
# epoch:553  d_loss:0.3175  g_loss:2.6670
# epoch:554  d_loss:0.2921  g_loss:2.2102
# epoch:555  d_loss:0.2650  g_loss:2.5849
# epoch:556  d_loss:0.2583  g_loss:2.4613
# epoch:557  d_loss:0.2665  g_loss:2.6453
# epoch:558  d_loss:0.2291  g_loss:2.6699
# epoch:559  d_loss:0.1138  g_loss:2.4775
# epoch:560  d_loss:0.1706  g_loss:2.6286
# epoch:561  d_loss:0.1269  g_loss:3.1303
# epoch:562  d_loss:0.1668  g_loss:3.4985
# epoch:563  d_loss:0.1518  g_loss:2.9255
# epoch:564  d_loss:0.1823  g_loss:3.2232
# epoch:565  d_loss:0.1518  g_loss:3.1633
# epoch:566  d_loss:0.1289  g_loss:3.0600
# epoch:567  d_loss:0.3214  g_loss:2.8132
# epoch:568  d_loss:0.2528  g_loss:2.6946
# epoch:569  d_loss:0.1900  g_loss:3.6363
# epoch:570  d_loss:0.2663  g_loss:3.3471
# epoch:571  d_loss:0.1783  g_loss:2.6047
# epoch:572  d_loss:0.3286  g_loss:2.3201
# epoch:573  d_loss:0.3913  g_loss:2.1449
# epoch:574  d_loss:0.2395  g_loss:2.5493
# epoch:575  d_loss:0.2033  g_loss:2.7936
# epoch:576  d_loss:0.2529  g_loss:2.6419
# epoch:577  d_loss:0.1264  g_loss:2.8865
# epoch:578  d_loss:0.2089  g_loss:2.8224
# epoch:579  d_loss:0.3656  g_loss:2.8756
# epoch:580  d_loss:0.2828  g_loss:2.8752
# epoch:581  d_loss:0.1755  g_loss:3.1879
# epoch:582  d_loss:0.3670  g_loss:3.8762
# epoch:583  d_loss:0.5095  g_loss:3.0773
# epoch:584  d_loss:0.3967  g_loss:2.0441
# epoch:585  d_loss:0.4101  g_loss:2.5613
# epoch:586  d_loss:0.2179  g_loss:3.4323
# epoch:587  d_loss:0.3676  g_loss:3.3568
# epoch:588  d_loss:0.2932  g_loss:3.7766
# epoch:589  d_loss:0.4031  g_loss:2.3271
# epoch:590  d_loss:0.5075  g_loss:1.7871
# epoch:591  d_loss:0.5437  g_loss:2.1988
# epoch:592  d_loss:0.3584  g_loss:2.3362
# epoch:593  d_loss:0.2965  g_loss:2.7264
# epoch:594  d_loss:0.4367  g_loss:2.3274
# epoch:595  d_loss:0.2687  g_loss:1.9899
# epoch:596  d_loss:0.2950  g_loss:2.2223
# epoch:597  d_loss:0.1828  g_loss:3.0225
# epoch:598  d_loss:0.1717  g_loss:3.5060
# epoch:599  d_loss:0.4740  g_loss:2.8517
# epoch:600  d_loss:0.2095  g_loss:2.1994
# epoch:601  d_loss:0.2693  g_loss:1.5565
# epoch:602  d_loss:0.3060  g_loss:2.1716
# epoch:603  d_loss:0.2026  g_loss:4.1312
# epoch:604  d_loss:0.4332  g_loss:2.8554
# epoch:605  d_loss:0.3722  g_loss:1.2033
# epoch:606  d_loss:0.3385  g_loss:1.3127
# epoch:607  d_loss:0.3448  g_loss:1.5428
# epoch:608  d_loss:0.3269  g_loss:2.6440
# epoch:609  d_loss:0.3772  g_loss:2.9015
# epoch:610  d_loss:0.4752  g_loss:1.8382
# epoch:611  d_loss:0.3632  g_loss:1.6298
# epoch:612  d_loss:0.5208  g_loss:1.0433
# epoch:613  d_loss:0.3499  g_loss:1.3708
# epoch:614  d_loss:0.5203  g_loss:1.2178
# epoch:615  d_loss:0.5598  g_loss:1.8544
# epoch:616  d_loss:0.5639  g_loss:1.9073
# epoch:617  d_loss:0.6444  g_loss:1.2990
# epoch:618  d_loss:0.6760  g_loss:0.9900
# epoch:619  d_loss:0.5626  g_loss:1.0710
# epoch:620  d_loss:0.4708  g_loss:1.7106
# epoch:621  d_loss:0.3975  g_loss:1.6321
# epoch:622  d_loss:0.4766  g_loss:1.9369
# epoch:623  d_loss:0.5640  g_loss:1.6777
# epoch:624  d_loss:0.6192  g_loss:1.6109
# epoch:625  d_loss:0.5103  g_loss:2.1140
# epoch:626  d_loss:0.2694  g_loss:3.2642
# epoch:627  d_loss:0.4945  g_loss:2.4375
# epoch:628  d_loss:0.6201  g_loss:1.5976
# epoch:629  d_loss:0.6478  g_loss:1.6092
# epoch:630  d_loss:0.6502  g_loss:2.3231
# epoch:631  d_loss:0.5736  g_loss:3.7673
# epoch:632  d_loss:0.4032  g_loss:5.5388
# epoch:633  d_loss:0.3969  g_loss:5.8519
# epoch:634  d_loss:0.4417  g_loss:5.6996
# epoch:635  d_loss:0.5006  g_loss:3.2230
# epoch:636  d_loss:1.0342  g_loss:1.4145
# epoch:637  d_loss:1.7017  g_loss:0.4385
# epoch:638  d_loss:1.0541  g_loss:1.0358
# epoch:639  d_loss:0.4162  g_loss:5.2158
# epoch:640  d_loss:0.8707  g_loss:7.1625
# epoch:641  d_loss:0.7247  g_loss:5.6806
# epoch:642  d_loss:0.5523  g_loss:2.7432
# epoch:643  d_loss:0.7618  g_loss:0.8712
# epoch:644  d_loss:1.1937  g_loss:0.8506
# epoch:645  d_loss:1.4517  g_loss:0.4766
# epoch:646  d_loss:1.1949  g_loss:1.0395
# epoch:647  d_loss:0.4901  g_loss:2.0395
# epoch:648  d_loss:0.8106  g_loss:2.8669
# epoch:649  d_loss:0.8767  g_loss:2.7940
# epoch:650  d_loss:0.7643  g_loss:2.7033
# epoch:651  d_loss:0.4545  g_loss:2.1700
# epoch:652  d_loss:0.2649  g_loss:2.3191
# epoch:653  d_loss:0.2185  g_loss:2.7774
# epoch:654  d_loss:0.2405  g_loss:3.6981
# epoch:655  d_loss:0.2066  g_loss:3.6835
# epoch:656  d_loss:0.1665  g_loss:4.1475
# epoch:657  d_loss:0.2448  g_loss:4.2348
# epoch:658  d_loss:0.2062  g_loss:4.4232
# epoch:659  d_loss:0.2444  g_loss:3.7478
# epoch:660  d_loss:0.3626  g_loss:3.8021
# epoch:661  d_loss:0.2202  g_loss:3.2747
# epoch:662  d_loss:0.2561  g_loss:3.0343
# epoch:663  d_loss:0.4176  g_loss:2.2527
# epoch:664  d_loss:0.2864  g_loss:2.4633
# epoch:665  d_loss:0.4317  g_loss:2.2780
# epoch:666  d_loss:0.6640  g_loss:1.5835
# epoch:667  d_loss:0.7826  g_loss:1.3966
# epoch:668  d_loss:0.6338  g_loss:1.2795
# epoch:669  d_loss:0.6754  g_loss:1.5264
# epoch:670  d_loss:0.5525  g_loss:1.6612
# epoch:671  d_loss:0.4842  g_loss:1.9960
# epoch:672  d_loss:0.5039  g_loss:2.4096
# epoch:673  d_loss:0.4539  g_loss:2.3185
# epoch:674  d_loss:0.3240  g_loss:2.2245
# epoch:675  d_loss:0.2695  g_loss:2.0982
# epoch:676  d_loss:0.4206  g_loss:1.9750
# epoch:677  d_loss:0.4050  g_loss:1.8667
# epoch:678  d_loss:0.5536  g_loss:1.8000
# epoch:679  d_loss:0.7386  g_loss:1.6290
# epoch:680  d_loss:0.5974  g_loss:1.6493
# epoch:681  d_loss:0.6776  g_loss:2.0912
# epoch:682  d_loss:0.8473  g_loss:1.9240
# epoch:683  d_loss:0.7112  g_loss:1.4065
# epoch:684  d_loss:0.4551  g_loss:1.9268
# epoch:685  d_loss:0.3221  g_loss:2.1468
# epoch:686  d_loss:0.3451  g_loss:2.5961
# epoch:687  d_loss:0.3352  g_loss:2.5146
# epoch:688  d_loss:0.3913  g_loss:2.9623
# epoch:689  d_loss:0.2855  g_loss:2.5176
# epoch:690  d_loss:0.2445  g_loss:2.3592
# epoch:691  d_loss:0.2374  g_loss:2.6089
# epoch:692  d_loss:0.2302  g_loss:2.8538
# epoch:693  d_loss:0.2627  g_loss:2.6651
# epoch:694  d_loss:0.2630  g_loss:2.5307
# epoch:695  d_loss:0.3671  g_loss:2.8262
# epoch:696  d_loss:0.1964  g_loss:2.9917
# epoch:697  d_loss:0.3293  g_loss:3.2039
# epoch:698  d_loss:0.2018  g_loss:2.9085
# epoch:699  d_loss:0.2667  g_loss:3.0726
# epoch:700  d_loss:0.2791  g_loss:3.4062
# epoch:701  d_loss:0.3470  g_loss:2.8402
# epoch:702  d_loss:0.3475  g_loss:2.6780
# epoch:703  d_loss:0.4070  g_loss:2.2781
# epoch:704  d_loss:0.5676  g_loss:2.3946
# epoch:705  d_loss:0.6638  g_loss:1.5653
# epoch:706  d_loss:0.5089  g_loss:1.5185
# epoch:707  d_loss:0.5997  g_loss:1.2506
# epoch:708  d_loss:0.5392  g_loss:1.2723
# epoch:709  d_loss:0.5731  g_loss:1.2560
# epoch:710  d_loss:0.6981  g_loss:1.2151
# epoch:711  d_loss:0.5562  g_loss:1.4332
# epoch:712  d_loss:0.4860  g_loss:1.4141
# epoch:713  d_loss:0.4914  g_loss:1.7441
# epoch:714  d_loss:0.4285  g_loss:1.7427
# epoch:715  d_loss:0.3883  g_loss:1.7325
# epoch:716  d_loss:0.3810  g_loss:1.9605
# epoch:717  d_loss:0.3030  g_loss:1.6379
# epoch:718  d_loss:0.2344  g_loss:1.9225
# epoch:719  d_loss:0.2442  g_loss:1.9426
# epoch:720  d_loss:0.1878  g_loss:2.5255
# epoch:721  d_loss:0.1621  g_loss:2.5547
# epoch:722  d_loss:0.2739  g_loss:2.5669
# epoch:723  d_loss:0.2466  g_loss:2.7372
# epoch:724  d_loss:0.2351  g_loss:2.5294
# epoch:725  d_loss:0.1465  g_loss:2.7455
# epoch:726  d_loss:0.1877  g_loss:2.5842
# epoch:727  d_loss:0.3300  g_loss:2.1342
# epoch:728  d_loss:0.1926  g_loss:2.3020
# epoch:729  d_loss:0.2499  g_loss:2.3409
# epoch:730  d_loss:0.2398  g_loss:2.4765
# epoch:731  d_loss:0.2015  g_loss:2.4991
# epoch:732  d_loss:0.2657  g_loss:2.3104
# epoch:733  d_loss:0.3988  g_loss:2.2617
# epoch:734  d_loss:0.2488  g_loss:3.1109
# epoch:735  d_loss:0.2514  g_loss:2.5390
# epoch:736  d_loss:0.4274  g_loss:2.3713
# epoch:737  d_loss:0.3866  g_loss:2.3116
# epoch:738  d_loss:0.2811  g_loss:1.6996
# epoch:739  d_loss:0.2855  g_loss:2.1281
# epoch:740  d_loss:0.4108  g_loss:1.9133
# epoch:741  d_loss:0.3655  g_loss:2.1568
# epoch:742  d_loss:0.4176  g_loss:1.8178
# epoch:743  d_loss:0.3247  g_loss:1.9914
# epoch:744  d_loss:0.6054  g_loss:1.7214
# epoch:745  d_loss:0.2916  g_loss:2.1169
# epoch:746  d_loss:0.3903  g_loss:1.5673
# epoch:747  d_loss:0.4780  g_loss:1.7196
# epoch:748  d_loss:0.3686  g_loss:2.1618
# epoch:749  d_loss:0.6252  g_loss:1.8373
# epoch:750  d_loss:0.3920  g_loss:1.4059
# epoch:751  d_loss:0.4425  g_loss:1.3444
# epoch:752  d_loss:0.4142  g_loss:1.4990
# epoch:753  d_loss:0.3946  g_loss:2.1736
# epoch:754  d_loss:0.3075  g_loss:2.1611
# epoch:755  d_loss:0.4129  g_loss:2.4104
# epoch:756  d_loss:0.3759  g_loss:2.3534
# epoch:757  d_loss:0.5369  g_loss:1.9389
# epoch:758  d_loss:0.4868  g_loss:1.6107
# epoch:759  d_loss:0.4696  g_loss:1.5813
# epoch:760  d_loss:0.5220  g_loss:1.5643
# epoch:761  d_loss:0.3819  g_loss:1.6071
# epoch:762  d_loss:0.5179  g_loss:1.6103
# epoch:763  d_loss:0.5607  g_loss:1.4765
# epoch:764  d_loss:0.3837  g_loss:1.6001
# epoch:765  d_loss:0.6000  g_loss:1.6658
# epoch:766  d_loss:0.5298  g_loss:1.2586
# epoch:767  d_loss:0.5368  g_loss:1.1228
# epoch:768  d_loss:0.6654  g_loss:2.0364
# epoch:769  d_loss:0.4886  g_loss:1.7819
# epoch:770  d_loss:0.6009  g_loss:2.0487
# epoch:771  d_loss:0.5402  g_loss:1.8191
# epoch:772  d_loss:0.4061  g_loss:2.2722
# epoch:773  d_loss:0.3887  g_loss:2.4292
# epoch:774  d_loss:0.5226  g_loss:2.0977
# epoch:775  d_loss:0.5159  g_loss:1.8408
# epoch:776  d_loss:0.4675  g_loss:1.9030
# epoch:777  d_loss:0.4713  g_loss:1.8530
# epoch:778  d_loss:0.3989  g_loss:2.0606
# epoch:779  d_loss:0.3522  g_loss:2.4129
# epoch:780  d_loss:0.4202  g_loss:2.2825
# epoch:781  d_loss:0.4312  g_loss:2.7149
# epoch:782  d_loss:0.4213  g_loss:2.2939
# epoch:783  d_loss:0.4690  g_loss:1.8860
# epoch:784  d_loss:0.5738  g_loss:1.4596
# epoch:785  d_loss:0.6596  g_loss:1.2635
# epoch:786  d_loss:0.5344  g_loss:1.1193
# epoch:787  d_loss:0.6563  g_loss:1.1164
# epoch:788  d_loss:0.5877  g_loss:1.3279
# epoch:789  d_loss:0.7355  g_loss:1.5035
# epoch:790  d_loss:0.9377  g_loss:1.4555
# epoch:791  d_loss:0.6894  g_loss:1.0900
# epoch:792  d_loss:0.7341  g_loss:1.2135
# epoch:793  d_loss:0.5393  g_loss:1.3651
# epoch:794  d_loss:0.5121  g_loss:1.4272
# epoch:795  d_loss:0.4659  g_loss:1.9365
# epoch:796  d_loss:0.3919  g_loss:2.0455
# epoch:797  d_loss:0.6295  g_loss:1.5278
# epoch:798  d_loss:0.3724  g_loss:1.7454
# epoch:799  d_loss:0.3165  g_loss:1.6216
# epoch:800  d_loss:0.5942  g_loss:1.6976
# epoch:801  d_loss:0.2617  g_loss:2.2911
# epoch:802  d_loss:0.4380  g_loss:2.2691
# epoch:803  d_loss:0.3388  g_loss:2.2892
# epoch:804  d_loss:0.3680  g_loss:2.3796
# epoch:805  d_loss:0.3363  g_loss:2.7125
# epoch:806  d_loss:0.4449  g_loss:2.5565
# epoch:807  d_loss:0.2698  g_loss:2.3013
# epoch:808  d_loss:0.5022  g_loss:2.2802
# epoch:809  d_loss:0.2905  g_loss:2.4062
# epoch:810  d_loss:0.4185  g_loss:2.2153
# epoch:811  d_loss:0.3751  g_loss:2.3488
# epoch:812  d_loss:0.4067  g_loss:2.1906
# epoch:813  d_loss:0.4327  g_loss:1.6455
# epoch:814  d_loss:0.4143  g_loss:1.7286
# epoch:815  d_loss:0.7493  g_loss:1.7200
# epoch:816  d_loss:0.6217  g_loss:1.4230
# epoch:817  d_loss:0.4717  g_loss:1.7161
# epoch:818  d_loss:0.8119  g_loss:1.4537
# epoch:819  d_loss:0.6866  g_loss:1.3869
# epoch:820  d_loss:0.8583  g_loss:1.2586
# epoch:821  d_loss:0.7909  g_loss:1.0671
# epoch:822  d_loss:0.7533  g_loss:1.0025
# epoch:823  d_loss:0.6658  g_loss:1.1399
# epoch:824  d_loss:0.7769  g_loss:1.3304
# epoch:825  d_loss:0.5310  g_loss:1.5956
# epoch:826  d_loss:0.3682  g_loss:2.2010
# epoch:827  d_loss:0.3448  g_loss:2.4052
# epoch:828  d_loss:0.2819  g_loss:2.8738
# epoch:829  d_loss:0.1918  g_loss:2.7456
# epoch:830  d_loss:0.2763  g_loss:2.5743
# epoch:831  d_loss:0.2726  g_loss:2.4149
# epoch:832  d_loss:0.3798  g_loss:1.8151
# epoch:833  d_loss:0.3781  g_loss:1.8317
# epoch:834  d_loss:0.3358  g_loss:1.9209
# epoch:835  d_loss:0.3739  g_loss:1.7785
# epoch:836  d_loss:0.3786  g_loss:2.3871
# epoch:837  d_loss:0.3000  g_loss:2.5511
# epoch:838  d_loss:0.3780  g_loss:2.9038
# epoch:839  d_loss:0.3753  g_loss:2.4000
# epoch:840  d_loss:0.4626  g_loss:2.2380
# epoch:841  d_loss:0.3531  g_loss:2.2291
# epoch:842  d_loss:0.2628  g_loss:2.2099
# epoch:843  d_loss:0.4010  g_loss:1.7829
# epoch:844  d_loss:0.6376  g_loss:2.2624
# epoch:845  d_loss:0.6182  g_loss:1.7589
# epoch:846  d_loss:0.4118  g_loss:2.2718
# epoch:847  d_loss:0.7336  g_loss:1.7872
# epoch:848  d_loss:0.7051  g_loss:1.3431
# epoch:849  d_loss:0.7594  g_loss:1.4797
# epoch:850  d_loss:0.7207  g_loss:1.1838
# epoch:851  d_loss:0.6562  g_loss:1.5373
# epoch:852  d_loss:0.6724  g_loss:1.3877
# epoch:853  d_loss:0.6060  g_loss:1.6580
# epoch:854  d_loss:0.5919  g_loss:1.5777
# epoch:855  d_loss:0.4894  g_loss:1.3838
# epoch:856  d_loss:0.3322  g_loss:1.7863
# epoch:857  d_loss:0.4150  g_loss:2.0648
# epoch:858  d_loss:0.4598  g_loss:1.7803
# epoch:859  d_loss:0.3807  g_loss:1.8730
# epoch:860  d_loss:0.3833  g_loss:2.3256
# epoch:861  d_loss:0.2493  g_loss:2.7247
# epoch:862  d_loss:0.3205  g_loss:2.6252
# epoch:863  d_loss:0.4391  g_loss:2.3585
# epoch:864  d_loss:0.4231  g_loss:1.8990
# epoch:865  d_loss:0.4783  g_loss:1.9858
# epoch:866  d_loss:0.4117  g_loss:1.9857
# epoch:867  d_loss:0.4534  g_loss:1.9840
# epoch:868  d_loss:0.5816  g_loss:1.6481
# epoch:869  d_loss:0.7266  g_loss:1.3442
# epoch:870  d_loss:0.5645  g_loss:1.5510
# epoch:871  d_loss:0.6480  g_loss:1.5225
# epoch:872  d_loss:0.6398  g_loss:1.0546
# epoch:873  d_loss:0.4701  g_loss:1.4629
# epoch:874  d_loss:0.5176  g_loss:1.3892
# epoch:875  d_loss:0.4030  g_loss:1.8703
# epoch:876  d_loss:0.3913  g_loss:1.9530
# epoch:877  d_loss:0.3278  g_loss:1.9913
# epoch:878  d_loss:0.3268  g_loss:2.3560
# epoch:879  d_loss:0.4500  g_loss:2.2564
# epoch:880  d_loss:0.2512  g_loss:2.6486
# epoch:881  d_loss:0.1796  g_loss:2.7006
# epoch:882  d_loss:0.3358  g_loss:2.1948
# epoch:883  d_loss:0.4121  g_loss:2.0847
# epoch:884  d_loss:0.4390  g_loss:1.9743
# epoch:885  d_loss:0.3057  g_loss:1.9816
# epoch:886  d_loss:0.4145  g_loss:1.6907
# epoch:887  d_loss:0.2177  g_loss:2.7059
# epoch:888  d_loss:0.3410  g_loss:2.1817
# epoch:889  d_loss:0.3046  g_loss:2.6398
# epoch:890  d_loss:0.4823  g_loss:1.7291
# epoch:891  d_loss:0.4297  g_loss:1.6797
# epoch:892  d_loss:0.4295  g_loss:1.7418
# epoch:893  d_loss:0.6053  g_loss:1.6737
# epoch:894  d_loss:0.7011  g_loss:1.4501
# epoch:895  d_loss:0.5354  g_loss:2.0982
# epoch:896  d_loss:0.5607  g_loss:1.9258
# epoch:897  d_loss:0.6669  g_loss:1.7670
# epoch:898  d_loss:0.4972  g_loss:1.8107
# epoch:899  d_loss:0.5185  g_loss:1.5716
# epoch:900  d_loss:0.4215  g_loss:1.5913
# epoch:901  d_loss:0.4475  g_loss:1.7255
# epoch:902  d_loss:0.4322  g_loss:2.1681
# epoch:903  d_loss:0.4022  g_loss:2.3598
# epoch:904  d_loss:0.4145  g_loss:2.4153
# epoch:905  d_loss:0.3840  g_loss:2.4774
# epoch:906  d_loss:0.4354  g_loss:2.0404
# epoch:907  d_loss:0.4258  g_loss:2.0046
# epoch:908  d_loss:0.3967  g_loss:1.7456
# epoch:909  d_loss:0.3632  g_loss:2.1489
# epoch:910  d_loss:0.4516  g_loss:1.8646
# epoch:911  d_loss:0.3972  g_loss:1.5974
# epoch:912  d_loss:0.4245  g_loss:1.8112
# epoch:913  d_loss:0.5820  g_loss:1.4044
# epoch:914  d_loss:0.5474  g_loss:1.8777
# epoch:915  d_loss:0.5030  g_loss:2.0132
# epoch:916  d_loss:0.4518  g_loss:1.7850
# epoch:917  d_loss:0.3942  g_loss:2.1593
# epoch:918  d_loss:0.4260  g_loss:1.9796
# epoch:919  d_loss:0.5344  g_loss:1.6929
# epoch:920  d_loss:0.5981  g_loss:1.6361
# epoch:921  d_loss:0.5636  g_loss:1.6815
# epoch:922  d_loss:0.2999  g_loss:2.2604
# epoch:923  d_loss:0.3018  g_loss:2.3115
# epoch:924  d_loss:0.3657  g_loss:2.7345
# epoch:925  d_loss:0.5252  g_loss:1.8730
# epoch:926  d_loss:0.4687  g_loss:1.6165
# epoch:927  d_loss:0.6007  g_loss:1.1771
# epoch:928  d_loss:0.5425  g_loss:1.0676
# epoch:929  d_loss:0.5723  g_loss:1.4320
# epoch:930  d_loss:0.3597  g_loss:1.9523
# epoch:931  d_loss:0.5088  g_loss:1.9223
# epoch:932  d_loss:0.4436  g_loss:1.9451
# epoch:933  d_loss:0.4191  g_loss:1.6862
# epoch:934  d_loss:0.5032  g_loss:1.4878
# epoch:935  d_loss:0.6151  g_loss:1.2790
# epoch:936  d_loss:0.3412  g_loss:1.2798
# epoch:937  d_loss:0.5416  g_loss:1.5358
# epoch:938  d_loss:0.3164  g_loss:1.9183
# epoch:939  d_loss:0.3690  g_loss:1.8878
# epoch:940  d_loss:0.4804  g_loss:1.7689
# epoch:941  d_loss:0.4121  g_loss:1.6728
# epoch:942  d_loss:0.3518  g_loss:1.9658
# epoch:943  d_loss:0.3057  g_loss:2.0369
# epoch:944  d_loss:0.2737  g_loss:1.8407
# epoch:945  d_loss:0.2645  g_loss:2.0748
# epoch:946  d_loss:0.2969  g_loss:1.9980
# epoch:947  d_loss:0.1905  g_loss:2.1450
# epoch:948  d_loss:0.2700  g_loss:2.2912
# epoch:949  d_loss:0.3797  g_loss:2.1341
# epoch:950  d_loss:0.2785  g_loss:1.9381
# epoch:951  d_loss:0.3405  g_loss:1.7028
# epoch:952  d_loss:0.4780  g_loss:1.8361
# epoch:953  d_loss:0.4580  g_loss:1.8340
# epoch:954  d_loss:0.4557  g_loss:2.0968
# epoch:955  d_loss:0.5654  g_loss:2.0403
# epoch:956  d_loss:0.4565  g_loss:1.5985
# epoch:957  d_loss:0.5247  g_loss:1.7002
# epoch:958  d_loss:0.4968  g_loss:1.7090
# epoch:959  d_loss:0.5117  g_loss:1.6219
# epoch:960  d_loss:0.4646  g_loss:2.1432
# epoch:961  d_loss:0.5643  g_loss:1.9772
# epoch:962  d_loss:0.7850  g_loss:1.5162
# epoch:963  d_loss:0.5151  g_loss:1.7256
# epoch:964  d_loss:0.5611  g_loss:1.6584
# epoch:965  d_loss:0.6173  g_loss:1.3755
# epoch:966  d_loss:0.4681  g_loss:1.4624
# epoch:967  d_loss:0.6675  g_loss:1.3073
# epoch:968  d_loss:0.5608  g_loss:1.4005
# epoch:969  d_loss:0.6032  g_loss:1.4710
# epoch:970  d_loss:0.5508  g_loss:1.8380
# epoch:971  d_loss:0.4430  g_loss:2.0788
# epoch:972  d_loss:0.5306  g_loss:1.7905
# epoch:973  d_loss:0.6480  g_loss:1.3928
# epoch:974  d_loss:0.5064  g_loss:1.5201
# epoch:975  d_loss:0.3662  g_loss:1.5244
# epoch:976  d_loss:0.4345  g_loss:1.5648
# epoch:977  d_loss:0.3657  g_loss:2.1596
# epoch:978  d_loss:0.3636  g_loss:2.0040
# epoch:979  d_loss:0.3466  g_loss:1.9911
# epoch:980  d_loss:0.3917  g_loss:1.7339
# epoch:981  d_loss:0.3509  g_loss:1.7151
# epoch:982  d_loss:0.4710  g_loss:1.7020
# epoch:983  d_loss:0.3754  g_loss:1.4779
# epoch:984  d_loss:0.3397  g_loss:2.0943
# epoch:985  d_loss:0.2570  g_loss:2.2614
# epoch:986  d_loss:0.4041  g_loss:2.2092
# epoch:987  d_loss:0.3723  g_loss:2.3447
# epoch:988  d_loss:0.3142  g_loss:2.2838
# epoch:989  d_loss:0.2599  g_loss:2.4363
# epoch:990  d_loss:0.3103  g_loss:2.4562
# epoch:991  d_loss:0.3405  g_loss:2.1228
# epoch:992  d_loss:0.3709  g_loss:1.8158
# epoch:993  d_loss:0.5261  g_loss:1.9289
# epoch:994  d_loss:0.4143  g_loss:2.2414
# epoch:995  d_loss:0.4165  g_loss:2.0719
# epoch:996  d_loss:0.5769  g_loss:1.6596
# epoch:997  d_loss:0.6155  g_loss:1.5863
# epoch:998  d_loss:0.5651  g_loss:1.5641
# epoch:999  d_loss:0.7049  g_loss:1.4806
# epoch:1000  d_loss:0.7629  g_loss:1.2878
# epoch:1001  d_loss:0.6404  g_loss:1.3321
# epoch:1002  d_loss:0.4724  g_loss:1.5613
# epoch:1003  d_loss:0.6206  g_loss:1.7554
# epoch:1004  d_loss:0.6643  g_loss:1.7634
# epoch:1005  d_loss:0.4582  g_loss:1.8918
# epoch:1006  d_loss:0.4283  g_loss:1.5636
# epoch:1007  d_loss:0.4496  g_loss:1.6368
# epoch:1008  d_loss:0.3826  g_loss:1.9856
# epoch:1009  d_loss:0.2970  g_loss:2.1944
# epoch:1010  d_loss:0.2648  g_loss:2.2157
# epoch:1011  d_loss:0.2678  g_loss:2.2672
# epoch:1012  d_loss:0.2659  g_loss:2.6370
# epoch:1013  d_loss:0.3264  g_loss:2.3279
# epoch:1014  d_loss:0.2575  g_loss:2.2060
# epoch:1015  d_loss:0.1688  g_loss:2.1352
# epoch:1016  d_loss:0.2264  g_loss:2.2473
# epoch:1017  d_loss:0.3518  g_loss:2.1989
# epoch:1018  d_loss:0.2037  g_loss:2.5661
# epoch:1019  d_loss:0.3206  g_loss:2.4193
# epoch:1020  d_loss:0.3197  g_loss:1.7425
# epoch:1021  d_loss:0.3817  g_loss:1.9063
# epoch:1022  d_loss:0.4091  g_loss:1.6599
# epoch:1023  d_loss:0.4617  g_loss:1.6643
# epoch:1024  d_loss:0.4643  g_loss:2.0322
# epoch:1025  d_loss:0.4472  g_loss:2.1382
# epoch:1026  d_loss:0.4677  g_loss:1.8668
# epoch:1027  d_loss:0.5194  g_loss:1.6410
# epoch:1028  d_loss:0.4605  g_loss:1.6807
# epoch:1029  d_loss:0.6528  g_loss:1.3586
# epoch:1030  d_loss:0.4419  g_loss:1.7641
# epoch:1031  d_loss:0.6167  g_loss:1.6636
# epoch:1032  d_loss:0.5339  g_loss:1.8985
# epoch:1033  d_loss:0.5511  g_loss:1.6576
# epoch:1034  d_loss:0.5877  g_loss:1.8419
# epoch:1035  d_loss:0.5217  g_loss:1.5234
# epoch:1036  d_loss:0.4074  g_loss:1.7941
# epoch:1037  d_loss:0.3442  g_loss:1.8574
# epoch:1038  d_loss:0.4650  g_loss:2.3033
# epoch:1039  d_loss:0.4091  g_loss:2.1409
# epoch:1040  d_loss:0.4565  g_loss:1.9890
# epoch:1041  d_loss:0.3315  g_loss:1.9681
# epoch:1042  d_loss:0.2456  g_loss:2.2431
# epoch:1043  d_loss:0.3101  g_loss:2.3559
# epoch:1044  d_loss:0.3069  g_loss:2.4267
# epoch:1045  d_loss:0.3959  g_loss:2.3728
# epoch:1046  d_loss:0.3088  g_loss:2.4477
# epoch:1047  d_loss:0.2601  g_loss:1.9231
# epoch:1048  d_loss:0.1646  g_loss:2.4517
# epoch:1049  d_loss:0.3817  g_loss:2.6081
# epoch:1050  d_loss:0.2614  g_loss:2.0517
# epoch:1051  d_loss:0.4387  g_loss:2.1457
# epoch:1052  d_loss:0.1894  g_loss:2.3665
# epoch:1053  d_loss:0.3536  g_loss:2.7115
# epoch:1054  d_loss:0.2429  g_loss:2.4991
# epoch:1055  d_loss:0.3380  g_loss:2.5807
# epoch:1056  d_loss:0.4090  g_loss:2.1998
# epoch:1057  d_loss:0.4232  g_loss:2.1734
# epoch:1058  d_loss:0.2744  g_loss:2.4206
# epoch:1059  d_loss:0.5098  g_loss:2.3015
# epoch:1060  d_loss:0.4914  g_loss:2.0885
# epoch:1061  d_loss:0.3627  g_loss:2.1812
# epoch:1062  d_loss:0.3865  g_loss:2.1590
# epoch:1063  d_loss:0.6499  g_loss:2.0382
# epoch:1064  d_loss:0.4869  g_loss:1.8839
# epoch:1065  d_loss:0.5767  g_loss:1.9472
# epoch:1066  d_loss:0.5000  g_loss:2.1387
# epoch:1067  d_loss:0.4511  g_loss:1.7955
# epoch:1068  d_loss:0.6003  g_loss:1.4565
# epoch:1069  d_loss:0.6297  g_loss:1.4823
# epoch:1070  d_loss:0.5088  g_loss:2.1168
# epoch:1071  d_loss:0.4671  g_loss:1.9200
# epoch:1072  d_loss:0.5490  g_loss:1.3739
# epoch:1073  d_loss:0.6161  g_loss:1.5708
# epoch:1074  d_loss:0.3464  g_loss:2.1701
# epoch:1075  d_loss:0.3275  g_loss:2.9004
# epoch:1076  d_loss:0.5366  g_loss:2.5419
# epoch:1077  d_loss:0.3091  g_loss:2.5469
# epoch:1078  d_loss:0.3591  g_loss:2.0469
# epoch:1079  d_loss:0.4094  g_loss:1.6225
# epoch:1080  d_loss:0.3514  g_loss:1.8987
# epoch:1081  d_loss:0.3676  g_loss:1.8989
# epoch:1082  d_loss:0.2694  g_loss:2.6946
# epoch:1083  d_loss:0.3094  g_loss:2.3375
# epoch:1084  d_loss:0.3254  g_loss:2.1321
# epoch:1085  d_loss:0.2245  g_loss:2.5445
# epoch:1086  d_loss:0.3107  g_loss:2.0681
# epoch:1087  d_loss:0.3126  g_loss:2.5865
# epoch:1088  d_loss:0.2524  g_loss:2.6904
# epoch:1089  d_loss:0.2911  g_loss:2.4675
# epoch:1090  d_loss:0.2177  g_loss:2.7346
# epoch:1091  d_loss:0.1989  g_loss:2.8468
# epoch:1092  d_loss:0.1835  g_loss:2.6282
# epoch:1093  d_loss:0.1419  g_loss:3.3691
# epoch:1094  d_loss:0.1912  g_loss:3.2074
# epoch:1095  d_loss:0.3022  g_loss:2.8776
# epoch:1096  d_loss:0.1315  g_loss:3.2122
# epoch:1097  d_loss:0.1991  g_loss:2.5495
# epoch:1098  d_loss:0.2463  g_loss:2.9919
# epoch:1099  d_loss:0.2591  g_loss:2.8490
# epoch:1100  d_loss:0.2204  g_loss:3.2956
# epoch:1101  d_loss:0.1828  g_loss:3.2139
# epoch:1102  d_loss:0.3491  g_loss:3.3032
# epoch:1103  d_loss:0.2915  g_loss:2.4836
# epoch:1104  d_loss:0.3037  g_loss:2.8317
# epoch:1105  d_loss:0.2521  g_loss:3.0521
# epoch:1106  d_loss:0.3241  g_loss:2.2486
# epoch:1107  d_loss:0.4131  g_loss:2.4902
# epoch:1108  d_loss:0.3716  g_loss:2.0003
# epoch:1109  d_loss:0.2654  g_loss:2.0081
# epoch:1110  d_loss:0.3268  g_loss:2.1982
# epoch:1111  d_loss:0.2715  g_loss:2.4825
# epoch:1112  d_loss:0.4139  g_loss:2.1089
# epoch:1113  d_loss:0.3862  g_loss:2.1394
# epoch:1114  d_loss:0.4782  g_loss:2.2563
# epoch:1115  d_loss:0.6170  g_loss:1.9743
# epoch:1116  d_loss:0.3886  g_loss:2.1343
# epoch:1117  d_loss:0.3513  g_loss:2.1971
# epoch:1118  d_loss:0.3318  g_loss:1.8051
# epoch:1119  d_loss:0.4237  g_loss:2.1323
# epoch:1120  d_loss:0.5690  g_loss:2.0603
# epoch:1121  d_loss:0.5084  g_loss:1.3183
# epoch:1122  d_loss:0.5268  g_loss:1.5843
# epoch:1123  d_loss:0.4369  g_loss:2.2101
# epoch:1124  d_loss:0.2656  g_loss:2.8680
# epoch:1125  d_loss:0.3846  g_loss:2.9408
# epoch:1126  d_loss:0.4417  g_loss:2.8490
# epoch:1127  d_loss:0.2874  g_loss:2.4616
# epoch:1128  d_loss:0.2391  g_loss:2.3874
# epoch:1129  d_loss:0.3944  g_loss:1.8752
# epoch:1130  d_loss:0.3004  g_loss:2.6444
# epoch:1131  d_loss:0.2920  g_loss:2.3146
# epoch:1132  d_loss:0.3630  g_loss:2.5147
# epoch:1133  d_loss:0.3444  g_loss:2.3958
# epoch:1134  d_loss:0.3496  g_loss:2.4663
# epoch:1135  d_loss:0.4021  g_loss:2.1790
# epoch:1136  d_loss:0.3007  g_loss:2.2308
# epoch:1137  d_loss:0.3658  g_loss:2.0563
# epoch:1138  d_loss:0.3145  g_loss:2.2949
# epoch:1139  d_loss:0.5282  g_loss:2.0639
# epoch:1140  d_loss:0.5243  g_loss:2.0559
# epoch:1141  d_loss:0.5070  g_loss:1.7108
# epoch:1142  d_loss:0.3366  g_loss:2.2916
# epoch:1143  d_loss:0.6367  g_loss:1.8025
# epoch:1144  d_loss:0.4973  g_loss:1.6280
# epoch:1145  d_loss:0.3799  g_loss:1.7787
# epoch:1146  d_loss:0.5327  g_loss:1.9723
# epoch:1147  d_loss:0.4039  g_loss:2.1555
# epoch:1148  d_loss:0.5773  g_loss:1.6583
# epoch:1149  d_loss:0.4406  g_loss:1.6031
# epoch:1150  d_loss:0.4422  g_loss:1.5508
# epoch:1151  d_loss:0.4429  g_loss:1.7241
# epoch:1152  d_loss:0.4470  g_loss:1.6800
# epoch:1153  d_loss:0.4449  g_loss:1.5698
# epoch:1154  d_loss:0.5340  g_loss:1.7773
# epoch:1155  d_loss:0.5709  g_loss:1.7509
# epoch:1156  d_loss:0.3134  g_loss:1.7845
# epoch:1157  d_loss:0.6334  g_loss:1.8207
# epoch:1158  d_loss:0.2838  g_loss:1.9701
# epoch:1159  d_loss:0.5368  g_loss:1.6341
# epoch:1160  d_loss:0.4481  g_loss:1.7448
# epoch:1161  d_loss:0.4415  g_loss:1.6191
# epoch:1162  d_loss:0.3651  g_loss:1.7926
# epoch:1163  d_loss:0.3594  g_loss:1.8679
# epoch:1164  d_loss:0.3253  g_loss:2.1402
# epoch:1165  d_loss:0.2881  g_loss:2.4606
# epoch:1166  d_loss:0.3562  g_loss:2.2117
# epoch:1167  d_loss:0.2559  g_loss:2.2128
# epoch:1168  d_loss:0.3328  g_loss:2.1849
# epoch:1169  d_loss:0.2497  g_loss:2.3334
# epoch:1170  d_loss:0.3739  g_loss:2.0648
# epoch:1171  d_loss:0.3736  g_loss:2.1894
# epoch:1172  d_loss:0.2363  g_loss:2.1344
# epoch:1173  d_loss:0.2723  g_loss:2.2134
# epoch:1174  d_loss:0.3788  g_loss:1.5852
# epoch:1175  d_loss:0.2851  g_loss:2.5120
# epoch:1176  d_loss:0.3021  g_loss:2.4129
# epoch:1177  d_loss:0.3632  g_loss:2.3303
# epoch:1178  d_loss:0.3422  g_loss:2.2055
# epoch:1179  d_loss:0.3111  g_loss:2.0380
# epoch:1180  d_loss:0.3928  g_loss:1.5471
# ...
# epoch:3620  d_loss:0.4316  g_loss:1.7847
# epoch:3621  d_loss:0.5271  g_loss:1.5653
# epoch:3622  d_loss:0.7390  g_loss:1.7069
# epoch:3623  d_loss:0.5793  g_loss:1.3329
# epoch:3624  d_loss:0.6373  g_loss:1.4674
# epoch:3625  d_loss:0.4486  g_loss:1.7907
# epoch:3626  d_loss:0.4844  g_loss:1.6629
# epoch:3627  d_loss:0.5188  g_loss:1.5917
# epoch:3628  d_loss:0.4055  g_loss:1.8317
# epoch:3629  d_loss:0.3183  g_loss:1.8981
# epoch:3630  d_loss:0.4404  g_loss:1.6324
# epoch:3631  d_loss:0.5654  g_loss:1.4218
# epoch:3632  d_loss:0.3400  g_loss:1.8250
# epoch:3633  d_loss:0.4114  g_loss:1.7303
# epoch:3634  d_loss:0.3893  g_loss:1.8148
# epoch:3635  d_loss:0.5200  g_loss:2.1018
# epoch:3636  d_loss:0.5305  g_loss:1.6771
# epoch:3637  d_loss:0.4096  g_loss:1.9938
# epoch:3638  d_loss:0.4614  g_loss:1.8733
# epoch:3639  d_loss:0.3756  g_loss:1.8403
# epoch:3640  d_loss:0.5277  g_loss:1.6648
# epoch:3641  d_loss:0.4190  g_loss:2.0811
# epoch:3642  d_loss:0.4979  g_loss:1.5752
# epoch:3643  d_loss:0.5439  g_loss:1.7604
# epoch:3644  d_loss:0.3919  g_loss:1.9028
# epoch:3645  d_loss:0.3913  g_loss:1.8167
# epoch:3646  d_loss:0.5374  g_loss:1.9204
# epoch:3647  d_loss:0.4568  g_loss:1.8811
# epoch:3648  d_loss:0.4175  g_loss:2.0883
# epoch:3649  d_loss:0.5591  g_loss:1.7257
# epoch:3650  d_loss:0.3639  g_loss:1.5782
# epoch:3651  d_loss:0.6028  g_loss:1.4549
# epoch:3652  d_loss:0.5369  g_loss:1.4937
# epoch:3653  d_loss:0.4138  g_loss:1.9043
# epoch:3654  d_loss:0.6262  g_loss:1.5426
# epoch:3655  d_loss:0.4422  g_loss:1.8579
# epoch:3656  d_loss:0.3999  g_loss:1.9525
# epoch:3657  d_loss:0.5416  g_loss:1.5810
# epoch:3658  d_loss:0.8032  g_loss:1.6581
# epoch:3659  d_loss:0.5697  g_loss:1.2310
# epoch:3660  d_loss:0.6641  g_loss:1.2660
# epoch:3661  d_loss:0.3191  g_loss:1.6616
# epoch:3662  d_loss:0.4445  g_loss:1.9762
# epoch:3663  d_loss:0.5292  g_loss:1.9308
# epoch:3664  d_loss:0.4067  g_loss:1.4627
# epoch:3665  d_loss:0.5281  g_loss:1.5570
# epoch:3666  d_loss:0.5944  g_loss:1.3289
# epoch:3667  d_loss:0.4093  g_loss:1.8427
# epoch:3668  d_loss:0.4119  g_loss:1.4513
# epoch:3669  d_loss:0.4584  g_loss:1.6270
# epoch:3670  d_loss:0.5243  g_loss:1.7918
# epoch:3671  d_loss:0.3962  g_loss:1.9178
# epoch:3672  d_loss:0.4974  g_loss:1.6152
# epoch:3673  d_loss:0.5662  g_loss:1.3716
# epoch:3674  d_loss:0.5668  g_loss:1.5688
# epoch:3675  d_loss:0.6637  g_loss:1.1638
# epoch:3676  d_loss:0.5690  g_loss:1.9252
# epoch:3677  d_loss:0.4418  g_loss:1.2842
# epoch:3678  d_loss:0.4587  g_loss:1.4404
# epoch:3679  d_loss:0.4214  g_loss:1.9810
# epoch:3680  d_loss:0.5615  g_loss:1.6404
# epoch:3681  d_loss:0.4699  g_loss:1.5706
# epoch:3682  d_loss:0.5048  g_loss:1.9974
# epoch:3683  d_loss:0.5813  g_loss:1.4319
# epoch:3684  d_loss:0.5398  g_loss:1.4999
# epoch:3685  d_loss:0.6179  g_loss:1.6743
# epoch:3686  d_loss:0.4124  g_loss:1.7634
# epoch:3687  d_loss:0.5914  g_loss:1.7255
# epoch:3688  d_loss:0.5096  g_loss:1.7388
# epoch:3689  d_loss:0.4154  g_loss:1.9340
# epoch:3690  d_loss:0.4545  g_loss:1.7990
# epoch:3691  d_loss:0.4791  g_loss:1.7594
# epoch:3692  d_loss:0.5179  g_loss:1.9594
# epoch:3693  d_loss:0.4209  g_loss:1.6188
# epoch:3694  d_loss:0.4238  g_loss:1.2711
# epoch:3695  d_loss:0.4151  g_loss:1.9362
# epoch:3696  d_loss:0.3661  g_loss:1.8219
# epoch:3697  d_loss:0.4077  g_loss:1.6558
# epoch:3698  d_loss:0.4956  g_loss:1.7346
# epoch:3699  d_loss:0.3529  g_loss:2.2433
# epoch:3700  d_loss:0.4443  g_loss:1.8506
# epoch:3701  d_loss:0.3439  g_loss:1.9224
# epoch:3702  d_loss:0.4407  g_loss:1.9734
# epoch:3703  d_loss:0.3725  g_loss:1.5439
# epoch:3704  d_loss:0.4938  g_loss:2.0189
# epoch:3705  d_loss:0.4499  g_loss:2.4098
# epoch:3706  d_loss:0.4635  g_loss:1.8393
# epoch:3707  d_loss:0.5180  g_loss:2.3056
# epoch:3708  d_loss:0.4773  g_loss:1.6909
# epoch:3709  d_loss:0.4961  g_loss:1.7070
# epoch:3710  d_loss:0.4882  g_loss:2.0388
# epoch:3711  d_loss:0.4173  g_loss:1.8208
# epoch:3712  d_loss:0.4857  g_loss:1.6961
# epoch:3713  d_loss:0.4201  g_loss:2.0900
# epoch:3714  d_loss:0.6915  g_loss:1.4099
# epoch:3715  d_loss:0.7625  g_loss:1.4338
# epoch:3716  d_loss:0.5695  g_loss:1.3394
# epoch:3717  d_loss:0.6041  g_loss:1.5475
# epoch:3718  d_loss:0.6292  g_loss:1.3576
# epoch:3719  d_loss:0.6393  g_loss:1.3278
# epoch:3720  d_loss:0.5592  g_loss:1.1255
# epoch:3721  d_loss:0.5591  g_loss:1.5938
# epoch:3722  d_loss:0.4758  g_loss:1.5601
# epoch:3723  d_loss:0.5836  g_loss:1.6317
# epoch:3724  d_loss:0.4530  g_loss:1.3597
# epoch:3725  d_loss:0.5318  g_loss:1.4125
# epoch:3726  d_loss:0.4089  g_loss:1.5796
# epoch:3727  d_loss:0.4641  g_loss:1.5318
# epoch:3728  d_loss:0.4373  g_loss:2.1284
# epoch:3729  d_loss:0.3385  g_loss:2.0689
# epoch:3730  d_loss:0.3825  g_loss:2.0348
# epoch:3731  d_loss:0.4902  g_loss:2.0116
# epoch:3732  d_loss:0.4430  g_loss:2.0823
# epoch:3733  d_loss:0.5047  g_loss:1.8845
# epoch:3734  d_loss:0.4608  g_loss:1.5642
# epoch:3735  d_loss:0.4667  g_loss:1.8442
# epoch:3736  d_loss:0.4043  g_loss:1.9960
# epoch:3737  d_loss:0.3331  g_loss:1.9516
# epoch:3738  d_loss:0.3589  g_loss:2.0661
# epoch:3739  d_loss:0.4616  g_loss:2.0865
# epoch:3740  d_loss:0.4348  g_loss:2.1158
# epoch:3741  d_loss:0.3822  g_loss:1.6422
# epoch:3742  d_loss:0.4749  g_loss:1.6389
# epoch:3743  d_loss:0.5075  g_loss:1.6360
# epoch:3744  d_loss:0.3748  g_loss:1.7758
# epoch:3745  d_loss:0.6055  g_loss:2.0012
# epoch:3746  d_loss:0.4983  g_loss:1.5764
# epoch:3747  d_loss:0.4556  g_loss:1.7188
# epoch:3748  d_loss:0.5155  g_loss:1.7276
# epoch:3749  d_loss:0.6485  g_loss:1.4853
# epoch:3750  d_loss:0.5770  g_loss:1.5239
# epoch:3751  d_loss:0.7453  g_loss:1.1648
# epoch:3752  d_loss:0.4429  g_loss:1.6275
# epoch:3753  d_loss:0.5247  g_loss:1.8378
# epoch:3754  d_loss:0.4121  g_loss:1.6460
# epoch:3755  d_loss:0.6047  g_loss:1.4472
# epoch:3756  d_loss:0.5911  g_loss:1.3652
# epoch:3757  d_loss:0.5247  g_loss:1.5378
# epoch:3758  d_loss:0.5001  g_loss:1.6889
# epoch:3759  d_loss:0.5258  g_loss:2.2213
# epoch:3760  d_loss:0.5318  g_loss:1.8083
# epoch:3761  d_loss:0.4982  g_loss:1.9839
# epoch:3762  d_loss:0.6245  g_loss:1.4622
# epoch:3763  d_loss:0.4895  g_loss:1.3162
# epoch:3764  d_loss:0.4406  g_loss:1.2426
# epoch:3765  d_loss:0.3652  g_loss:2.0462
# epoch:3766  d_loss:0.4227  g_loss:2.1703
# epoch:3767  d_loss:0.3808  g_loss:2.1642
# epoch:3768  d_loss:0.4323  g_loss:1.9733
# epoch:3769  d_loss:0.3455  g_loss:1.9478
# epoch:3770  d_loss:0.4076  g_loss:2.1290
# epoch:3771  d_loss:0.4699  g_loss:1.3137
# epoch:3772  d_loss:0.3520  g_loss:1.5364
# epoch:3773  d_loss:0.5491  g_loss:1.8840
# epoch:3774  d_loss:0.4045  g_loss:1.5738
# epoch:3775  d_loss:0.4463  g_loss:1.7640
# epoch:3776  d_loss:0.3688  g_loss:2.5083
# epoch:3777  d_loss:0.3951  g_loss:2.4429
# epoch:3778  d_loss:0.4887  g_loss:2.1383
# epoch:3779  d_loss:0.4468  g_loss:1.8231
# epoch:3780  d_loss:0.5788  g_loss:1.6428
# epoch:3781  d_loss:0.5178  g_loss:1.3929
# epoch:3782  d_loss:0.4866  g_loss:1.4949
# epoch:3783  d_loss:0.4547  g_loss:1.7909
# epoch:3784  d_loss:0.4921  g_loss:1.7898
# epoch:3785  d_loss:0.6378  g_loss:1.7882
# epoch:3786  d_loss:0.7234  g_loss:1.6805
# epoch:3787  d_loss:0.4927  g_loss:1.4837
# epoch:3788  d_loss:0.6521  g_loss:1.0992
# epoch:3789  d_loss:0.6319  g_loss:1.4931
# epoch:3790  d_loss:0.5427  g_loss:1.4655
# epoch:3791  d_loss:0.5043  g_loss:1.7910
# epoch:3792  d_loss:0.4950  g_loss:2.1227
# epoch:3793  d_loss:0.6127  g_loss:1.6908
# epoch:3794  d_loss:0.4707  g_loss:1.4029
# epoch:3795  d_loss:0.6103  g_loss:1.3148
# epoch:3796  d_loss:0.5585  g_loss:1.3633
# epoch:3797  d_loss:0.4495  g_loss:1.3015
# epoch:3798  d_loss:0.3983  g_loss:1.9162
# epoch:3799  d_loss:0.4088  g_loss:1.6308
# epoch:3800  d_loss:0.4209  g_loss:2.1359
# epoch:3801  d_loss:0.5097  g_loss:1.7841
# epoch:3802  d_loss:0.4334  g_loss:1.8075
# epoch:3803  d_loss:0.5707  g_loss:1.6466
# epoch:3804  d_loss:0.4035  g_loss:1.8310
# epoch:3805  d_loss:0.4815  g_loss:1.9102
# epoch:3806  d_loss:0.3754  g_loss:1.7594
# epoch:3807  d_loss:0.4777  g_loss:1.8466
# epoch:3808  d_loss:0.5879  g_loss:1.5065
# epoch:3809  d_loss:0.5655  g_loss:1.3340
# epoch:3810  d_loss:0.4929  g_loss:1.7471
# epoch:3811  d_loss:0.4157  g_loss:1.9299
# epoch:3812  d_loss:0.4947  g_loss:1.9315
# epoch:3813  d_loss:0.4311  g_loss:1.6234
# epoch:3814  d_loss:0.5021  g_loss:1.4510
# epoch:3815  d_loss:0.4149  g_loss:1.5659
# epoch:3816  d_loss:0.4184  g_loss:1.4743
# epoch:3817  d_loss:0.5556  g_loss:1.7397
# epoch:3818  d_loss:0.4745  g_loss:1.7551
# epoch:3819  d_loss:0.4976  g_loss:1.7678
# epoch:3820  d_loss:0.5369  g_loss:1.6267
# epoch:3821  d_loss:0.5521  g_loss:1.6238
# epoch:3822  d_loss:0.5216  g_loss:1.6032
# epoch:3823  d_loss:0.3769  g_loss:1.7157
# epoch:3824  d_loss:0.5404  g_loss:2.1664
# epoch:3825  d_loss:0.3639  g_loss:2.3152
# epoch:3826  d_loss:0.4281  g_loss:2.1434
# epoch:3827  d_loss:0.4478  g_loss:1.9796
# epoch:3828  d_loss:0.3537  g_loss:1.6453
# epoch:3829  d_loss:0.5912  g_loss:1.5094
# epoch:3830  d_loss:0.4278  g_loss:1.5654
# epoch:3831  d_loss:0.4412  g_loss:2.1114
# epoch:3832  d_loss:0.4519  g_loss:2.1532
# epoch:3833  d_loss:0.4806  g_loss:1.8883
# epoch:3834  d_loss:0.5321  g_loss:2.0758
# epoch:3835  d_loss:0.4913  g_loss:1.9171
# epoch:3836  d_loss:0.5021  g_loss:1.6078
# epoch:3837  d_loss:0.5112  g_loss:1.3871
# epoch:3838  d_loss:0.3959  g_loss:1.5759
# epoch:3839  d_loss:0.4163  g_loss:1.4840
# epoch:3840  d_loss:0.4155  g_loss:1.9080
# epoch:3841  d_loss:0.4800  g_loss:2.0042
# epoch:3842  d_loss:0.5208  g_loss:1.8885
# epoch:3843  d_loss:0.3505  g_loss:2.1570
# epoch:3844  d_loss:0.5608  g_loss:1.9580
# epoch:3845  d_loss:0.4285  g_loss:1.7759
# epoch:3846  d_loss:0.5778  g_loss:1.6671
# epoch:3847  d_loss:0.4184  g_loss:1.8906
# epoch:3848  d_loss:0.4036  g_loss:1.5608
# epoch:3849  d_loss:0.4914  g_loss:1.6552
# epoch:3850  d_loss:0.5761  g_loss:1.3520
# epoch:3851  d_loss:0.4095  g_loss:1.5564
# epoch:3852  d_loss:0.3841  g_loss:1.9285
# epoch:3853  d_loss:0.5043  g_loss:1.7024
# epoch:3854  d_loss:0.4422  g_loss:1.7514
# epoch:3855  d_loss:0.5936  g_loss:1.3776
# epoch:3856  d_loss:0.5273  g_loss:1.5426
# epoch:3857  d_loss:0.5126  g_loss:1.4762
# epoch:3858  d_loss:0.4112  g_loss:1.8303
# epoch:3859  d_loss:0.4843  g_loss:1.7935
# epoch:3860  d_loss:0.4990  g_loss:1.6065
# epoch:3861  d_loss:0.4061  g_loss:2.1421
# epoch:3862  d_loss:0.5595  g_loss:2.2081
# epoch:3863  d_loss:0.4489  g_loss:1.9028
# epoch:3864  d_loss:0.3034  g_loss:1.9436
# epoch:3865  d_loss:0.4517  g_loss:1.5592
# epoch:3866  d_loss:0.5708  g_loss:1.5641
# epoch:3867  d_loss:0.4156  g_loss:1.5506
# epoch:3868  d_loss:0.4407  g_loss:2.1438
# epoch:3869  d_loss:0.4621  g_loss:1.7873
# epoch:3870  d_loss:0.5001  g_loss:1.7171
# epoch:3871  d_loss:0.5201  g_loss:1.4512
# epoch:3872  d_loss:0.4648  g_loss:1.4223
# epoch:3873  d_loss:0.4426  g_loss:1.4869
# epoch:3874  d_loss:0.4811  g_loss:1.5462
# epoch:3875  d_loss:0.4270  g_loss:1.5551
# epoch:3876  d_loss:0.4624  g_loss:1.9489
# epoch:3877  d_loss:0.5525  g_loss:1.6720
# epoch:3878  d_loss:0.5074  g_loss:2.0555
# epoch:3879  d_loss:0.5214  g_loss:1.7113
# epoch:3880  d_loss:0.3275  g_loss:1.9985
# epoch:3881  d_loss:0.3318  g_loss:1.4497
# epoch:3882  d_loss:0.3764  g_loss:1.7234
# epoch:3883  d_loss:0.6933  g_loss:1.5377
# epoch:3884  d_loss:0.5444  g_loss:1.5964
# epoch:3885  d_loss:0.4766  g_loss:2.1079
# epoch:3886  d_loss:0.5845  g_loss:1.8994
# epoch:3887  d_loss:0.4491  g_loss:1.6564
# epoch:3888  d_loss:0.5491  g_loss:1.7391
# epoch:3889  d_loss:0.5990  g_loss:1.7524
# epoch:3890  d_loss:0.6957  g_loss:1.5180
# epoch:3891  d_loss:0.5398  g_loss:1.5795
# epoch:3892  d_loss:0.4827  g_loss:1.7891
# epoch:3893  d_loss:0.5431  g_loss:1.7120
# epoch:3894  d_loss:0.4400  g_loss:1.7861
# epoch:3895  d_loss:0.4589  g_loss:1.4203
# epoch:3896  d_loss:0.3366  g_loss:1.5918
# epoch:3897  d_loss:0.4445  g_loss:1.6336
# epoch:3898  d_loss:0.4508  g_loss:1.7470
# epoch:3899  d_loss:0.4533  g_loss:1.5943
# epoch:3900  d_loss:0.4201  g_loss:1.3665
# epoch:3901  d_loss:0.5182  g_loss:1.3301
# epoch:3902  d_loss:0.6002  g_loss:1.2860
# epoch:3903  d_loss:0.4719  g_loss:1.5354
# epoch:3904  d_loss:0.4603  g_loss:1.9776
# epoch:3905  d_loss:0.4248  g_loss:2.1308
# epoch:3906  d_loss:0.5012  g_loss:1.8289
# epoch:3907  d_loss:0.6269  g_loss:1.5512
# epoch:3908  d_loss:0.4597  g_loss:1.5886
# epoch:3909  d_loss:0.4850  g_loss:1.4310
# epoch:3910  d_loss:0.4445  g_loss:1.5668
# epoch:3911  d_loss:0.7007  g_loss:1.0705
# epoch:3912  d_loss:0.5248  g_loss:1.6150
# epoch:3913  d_loss:0.5349  g_loss:1.6537
# epoch:3914  d_loss:0.4249  g_loss:1.5017
# epoch:3915  d_loss:0.5115  g_loss:1.4152
# epoch:3916  d_loss:0.3655  g_loss:1.7040
# epoch:3917  d_loss:0.6410  g_loss:1.6633
# epoch:3918  d_loss:0.4420  g_loss:1.6121
# epoch:3919  d_loss:0.5370  g_loss:1.6036
# epoch:3920  d_loss:0.3895  g_loss:1.3423
# epoch:3921  d_loss:0.4190  g_loss:1.5720
# epoch:3922  d_loss:0.4960  g_loss:1.5635
# epoch:3923  d_loss:0.4672  g_loss:1.6177
# epoch:3924  d_loss:0.4738  g_loss:1.4788
# epoch:3925  d_loss:0.4952  g_loss:1.6936
# epoch:3926  d_loss:0.4476  g_loss:1.7623
# epoch:3927  d_loss:0.4774  g_loss:1.5222
# epoch:3928  d_loss:0.4531  g_loss:1.6581
# epoch:3929  d_loss:0.4696  g_loss:1.6592
# epoch:3930  d_loss:0.4293  g_loss:1.9936
# epoch:3931  d_loss:0.4390  g_loss:2.0540
# epoch:3932  d_loss:0.4253  g_loss:1.5829
# epoch:3933  d_loss:0.5513  g_loss:2.0639
# epoch:3934  d_loss:0.3774  g_loss:1.9053
# epoch:3935  d_loss:0.5161  g_loss:1.4355
# epoch:3936  d_loss:0.5932  g_loss:1.4424
# epoch:3937  d_loss:0.6932  g_loss:1.0413
# epoch:3938  d_loss:0.4544  g_loss:1.3286
# epoch:3939  d_loss:0.4618  g_loss:1.3725
# epoch:3940  d_loss:0.5680  g_loss:1.3816
# epoch:3941  d_loss:0.4907  g_loss:1.5009
# epoch:3942  d_loss:0.4558  g_loss:1.6689
# epoch:3943  d_loss:0.4532  g_loss:1.2820
# epoch:3944  d_loss:0.6102  g_loss:1.5393
# epoch:3945  d_loss:0.5659  g_loss:1.2803
# epoch:3946  d_loss:0.5833  g_loss:1.6377
# epoch:3947  d_loss:0.5591  g_loss:1.3900
# epoch:3948  d_loss:0.6368  g_loss:1.6055
# epoch:3949  d_loss:0.4647  g_loss:1.2373
# epoch:3950  d_loss:0.5371  g_loss:1.2540
# epoch:3951  d_loss:0.4800  g_loss:1.3366
# epoch:3952  d_loss:0.5857  g_loss:1.6828
# epoch:3953  d_loss:0.4899  g_loss:1.6637
# epoch:3954  d_loss:0.4864  g_loss:1.6080
# epoch:3955  d_loss:0.3856  g_loss:1.9389
# epoch:3956  d_loss:0.4375  g_loss:1.8381
# epoch:3957  d_loss:0.4087  g_loss:1.9673
# epoch:3958  d_loss:0.4721  g_loss:1.5835
# epoch:3959  d_loss:0.4439  g_loss:1.8254
# epoch:3960  d_loss:0.5497  g_loss:2.1039
# epoch:3961  d_loss:0.3151  g_loss:2.0239
# epoch:3962  d_loss:0.4120  g_loss:1.8110
# epoch:3963  d_loss:0.6460  g_loss:2.0628
# epoch:3964  d_loss:0.5612  g_loss:1.5750
# epoch:3965  d_loss:0.5197  g_loss:1.4369
# epoch:3966  d_loss:0.6325  g_loss:1.3585
# epoch:3967  d_loss:0.4418  g_loss:1.4546
# epoch:3968  d_loss:0.5432  g_loss:1.5920
# epoch:3969  d_loss:0.4813  g_loss:1.7659
# epoch:3970  d_loss:0.4653  g_loss:1.7168
# epoch:3971  d_loss:0.4394  g_loss:1.8422
# epoch:3972  d_loss:0.5924  g_loss:1.6904
# epoch:3973  d_loss:0.3591  g_loss:1.8663
# epoch:3974  d_loss:0.5159  g_loss:1.7053
# epoch:3975  d_loss:0.5278  g_loss:1.1302
# epoch:3976  d_loss:0.4672  g_loss:1.5688
# epoch:3977  d_loss:0.5496  g_loss:1.7297
# epoch:3978  d_loss:0.3947  g_loss:1.9325
# epoch:3979  d_loss:0.6849  g_loss:1.7206
# epoch:3980  d_loss:0.5210  g_loss:2.0838
# epoch:3981  d_loss:0.5699  g_loss:1.4812
# epoch:3982  d_loss:0.4390  g_loss:1.2443
# epoch:3983  d_loss:0.6317  g_loss:1.3653
# epoch:3984  d_loss:0.4405  g_loss:1.6437
# epoch:3985  d_loss:0.5367  g_loss:1.4729
# epoch:3986  d_loss:0.5601  g_loss:1.7271
# epoch:3987  d_loss:0.5868  g_loss:1.4819
# epoch:3988  d_loss:0.5380  g_loss:1.3972
# epoch:3989  d_loss:0.3927  g_loss:1.8464
# epoch:3990  d_loss:0.5481  g_loss:1.5099
# epoch:3991  d_loss:0.4943  g_loss:1.4511
# epoch:3992  d_loss:0.4712  g_loss:1.8470
# epoch:3993  d_loss:0.5464  g_loss:1.5254
# epoch:3994  d_loss:0.4203  g_loss:1.7696
# epoch:3995  d_loss:0.5077  g_loss:1.4776
# epoch:3996  d_loss:0.4226  g_loss:1.6777
# epoch:3997  d_loss:0.4231  g_loss:1.5550
# epoch:3998  d_loss:0.5158  g_loss:1.7611
# epoch:3999  d_loss:0.4724  g_loss:2.0030
# epoch:4000  d_loss:0.3888  g_loss:1.5048
# C:\Users\asus\anaconda3\envs\django3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
